# %% [markdown]
# ## Practical Exam: Loan Insights
# <p>EasyLoan offers a wide range of loan services, including personal loans, car loans, and mortgages.</p>
# <p>EasyLoan offers loans to clients from Canada, United Kingdom and United States.</p>
# <p>The analytics team wants to report performance across different geographic areas. They aim to identify areas of strength and weakness for the business strategy team.</p>
# <p>They need your help to ensure the data is accessible and reliable before they start reporting.</p>
# <p>The data you need is in the database named <code>lending</code>.</p>
# <p><strong>Database Schema</strong></p>
# <p><img src="https://assets.datacamp.com/production/project_1748/img/lending_schema.png" alt="database schema"></p>
# <h2 id="task1">Task 1</h2>
# <p>The analytics team wants to use the <code>client</code> table to create a dashboard for client details. For them to proceed, they need to be sure the data is clean enough to use.</p>
# <p>The <code>client</code> table below illustrates what the analytics team expects the data types and format to be.</p>
# <table>
# <thead>
# <tr>
# <th>Column Name</th>
# <th>Description</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>client_id</td>
# <td>Unique integer (set by the database, can’t take any other value)</td>
# </tr>
# <tr>
# <td>date_of_birth</td>
# <td>Date of birth of the client, as a date  (format: YYYY-MM-DD)</td>
# </tr>
# <tr>
# <td>employment_status</td>
# <td>Current employment status of the client, either employed or unemployed, as a lower case string</td>
# </tr>
# <tr>
# <td>country</td>
# <td>The country where the client resides, either USA, UK or CA, as an upper case string</td>
# </tr>
# </tbody>
# </table>
# <p>Write a query to ensure that the <code>client</code> table matches the description provided. Your query should not update the <code>client</code> table.</p>

# %%
# %%sql
# postgresql:///lending
#
# -- Keep the two lines above
# -- Start your answers here..
# SELECT client_id,
#     TO_DATE(date_of_birth, 'Month DD, YYYY') AS date_of_birth,
#     CASE
#         WHEN employment_status = 'unemployed' THEN 'unemployed'
#         ELSE 'employed'
#     END AS employment_status,
#     UPPER(country) as country
# FROM client;
# Out:
# 300 rows affected.
# [(1, datetime.date(1963, 7, 8), 'unemployed', 'USA'),
#  (2, datetime.date(1957, 2, 7), 'unemployed', 'UK'),
#  (3, datetime.date(1993, 2, 21), 'employed', 'CA'),
#  (4, datetime.date(1978, 3, 19), 'employed', 'CA'),
#  (5, datetime.date(2000, 10, 2), 'employed', 'USA'),
#  (6, datetime.date(1974, 8, 5), 'unemployed', 'USA'),
#  (7, datetime.date(1980, 7, 14), 'employed', 'UK'),
#  (8, datetime.date(1995, 6, 24), 'unemployed', 'USA'),
#  (9, datetime.date(1962, 2, 21), 'unemployed', 'USA'),
#  (10, datetime.date(1992, 5, 28), 'employed', 'CA'),
#  (11, datetime.date(2001, 11, 30), 'employed', 'CA'),
#  (12, datetime.date(1981, 2, 5), 'unemployed', 'USA'),
#  (13, datetime.date(1960, 7, 16), 'unemployed', 'UK'),
#  (14, datetime.date(1962, 6, 15), 'employed', 'USA'),
#  (15, datetime.date(1990, 6, 27), 'employed', 'UK'),
#  (16, datetime.date(1975, 3, 20), 'unemployed', 'UK'),
#  (17, datetime.date(1959, 2, 20), 'unemployed', 'CA'),
#  (18, datetime.date(1991, 2, 25), 'unemployed', 'CA'),
#  (19, datetime.date(2001, 2, 20), 'unemployed', 'CA'),
#  (20, datetime.date(1988, 6, 10), 'unemployed', 'UK'),
#  (21, datetime.date(2002, 1, 19), 'employed', 'USA'),
#  (22, datetime.date(1972, 3, 30), 'unemployed', 'CA'),
#  (23, datetime.date(1970, 12, 15), 'unemployed', 'CA'),
#  (24, datetime.date(1956, 11, 16), 'employed', 'USA'),
#  (25, datetime.date(1999, 4, 1), 'unemployed', 'CA'),
#  (26, datetime.date(1978, 11, 19), 'employed', 'USA'),
#  (27, datetime.date(1969, 8, 23), 'employed', 'UK'),
#  (28, datetime.date(1956, 11, 26), 'unemployed', 'UK'),
#  (29, datetime.date(1997, 5, 11), 'employed', 'CA'),
#  (30, datetime.date(1983, 6, 29), 'employed', 'CA'),
#  (31, datetime.date(2000, 10, 6), 'employed', 'UK'),
#  (32, datetime.date(1991, 7, 24), 'employed', 'USA'),
#  (33, datetime.date(1976, 12, 16), 'employed', 'UK'),
#  (34, datetime.date(1969, 7, 22), 'unemployed', 'USA'),
#  (35, datetime.date(1992, 8, 16), 'employed', 'UK'),
#  (36, datetime.date(2000, 8, 21), 'employed', 'UK'),
#  (37, datetime.date(1991, 2, 7), 'employed', 'UK'),
#  (38, datetime.date(1991, 5, 21), 'employed', 'USA'),
#  (39, datetime.date(1977, 12, 31), 'unemployed', 'USA'),
#  (40, datetime.date(1973, 5, 16), 'employed', 'CA'),
#  (41, datetime.date(2002, 5, 13), 'employed', 'USA'),
#  (42, datetime.date(1971, 2, 10), 'unemployed', 'USA'),
#  (43, datetime.date(1990, 12, 19), 'unemployed', 'CA'),
#  (44, datetime.date(1971, 6, 5), 'employed', 'USA'),
#  (45, datetime.date(1962, 1, 31), 'employed', 'USA'),
#  (46, datetime.date(1956, 10, 4), 'employed', 'USA'),
#  (47, datetime.date(1956, 6, 18), 'employed', 'CA'),
#  (48, datetime.date(1993, 7, 25), 'unemployed', 'CA'),
#  (49, datetime.date(1959, 3, 29), 'employed', 'USA'),
#  (50, datetime.date(1997, 7, 26), 'unemployed', 'USA'),
#  (51, datetime.date(1992, 12, 3), 'unemployed', 'CA'),
#  (52, datetime.date(1965, 11, 3), 'employed', 'USA'),
#  (53, datetime.date(1955, 7, 3), 'employed', 'UK'),
#  (54, datetime.date(2004, 8, 20), 'employed', 'USA'),
#  (55, datetime.date(1998, 11, 2), 'employed', 'UK'),
#  (56, datetime.date(1967, 9, 24), 'unemployed', 'USA'),
#  (57, datetime.date(1958, 3, 9), 'employed', 'USA'),
#  (58, datetime.date(1972, 5, 29), 'unemployed', 'USA'),
#  (59, datetime.date(1977, 3, 15), 'employed', 'UK'),
#  (60, datetime.date(1991, 3, 4), 'employed', 'CA'),
#  (61, datetime.date(1967, 12, 7), 'employed', 'CA'),
#  (62, datetime.date(1966, 7, 20), 'unemployed', 'CA'),
#  (63, datetime.date(1957, 10, 1), 'unemployed', 'USA'),
#  (64, datetime.date(2004, 10, 8), 'employed', 'CA'),
#  (65, datetime.date(1965, 11, 7), 'employed', 'CA'),
#  (66, datetime.date(1975, 3, 14), 'unemployed', 'CA'),
#  (67, datetime.date(1962, 12, 26), 'unemployed', 'USA'),
#  (68, datetime.date(1989, 10, 4), 'employed', 'USA'),
#  (69, datetime.date(1985, 3, 17), 'unemployed', 'CA'),
#  (70, datetime.date(1955, 10, 7), 'employed', 'USA'),
#  (71, datetime.date(1986, 9, 1), 'unemployed', 'CA'),
#  (72, datetime.date(1974, 12, 6), 'employed', 'CA'),
#  (73, datetime.date(1979, 9, 9), 'unemployed', 'USA'),
#  (74, datetime.date(1975, 10, 27), 'employed', 'CA'),
#  (75, datetime.date(1963, 5, 29), 'unemployed', 'UK'),
#  (76, datetime.date(1957, 9, 16), 'unemployed', 'USA'),
#  (77, datetime.date(1973, 2, 20), 'employed', 'UK'),
#  (78, datetime.date(1991, 7, 7), 'unemployed', 'UK'),
#  (79, datetime.date(1968, 3, 25), 'employed', 'USA'),
#  (80, datetime.date(1986, 8, 30), 'employed', 'USA'),
#  (81, datetime.date(1995, 4, 8), 'employed', 'UK'),
#  (82, datetime.date(1979, 8, 13), 'employed', 'UK'),
#  (83, datetime.date(1979, 12, 10), 'unemployed', 'UK'),
#  (84, datetime.date(1972, 9, 21), 'unemployed', 'CA'),
#  (85, datetime.date(1971, 4, 20), 'unemployed', 'CA'),
#  (86, datetime.date(1955, 5, 2), 'unemployed', 'USA'),
#  (87, datetime.date(1956, 11, 17), 'unemployed', 'UK'),
#  (88, datetime.date(1987, 12, 14), 'unemployed', 'USA'),
#  (89, datetime.date(1999, 10, 23), 'employed', 'USA'),
#  (90, datetime.date(1957, 2, 13), 'unemployed', 'UK'),
#  (91, datetime.date(2000, 2, 23), 'unemployed', 'CA'),
#  (92, datetime.date(1989, 5, 22), 'employed', 'USA'),
#  (93, datetime.date(1995, 3, 25), 'employed', 'USA'),
#  (94, datetime.date(1989, 7, 5), 'employed', 'CA'),
#  (95, datetime.date(1971, 11, 22), 'unemployed', 'USA'),
#  (96, datetime.date(1974, 2, 4), 'unemployed', 'UK'),
#  (97, datetime.date(2004, 3, 30), 'employed', 'UK'),
#  (98, datetime.date(1995, 1, 30), 'employed', 'CA'),
#  (99, datetime.date(1983, 12, 14), 'employed', 'UK'),
#  (100, datetime.date(2003, 5, 12), 'employed', 'UK'),
#  (101, datetime.date(1995, 7, 22), 'employed', 'USA'),
#  (102, datetime.date(1999, 6, 8), 'employed', 'CA'),
#  (103, datetime.date(2002, 5, 11), 'employed', 'UK'),
#  (104, datetime.date(1978, 5, 12), 'unemployed', 'UK'),
#  (105, datetime.date(1992, 8, 1), 'unemployed', 'USA'),
#  (106, datetime.date(1967, 2, 11), 'employed', 'UK'),
#  (107, datetime.date(1983, 8, 14), 'unemployed', 'UK'),
#  (108, datetime.date(1990, 10, 18), 'employed', 'UK'),
#  (109, datetime.date(1994, 6, 7), 'employed', 'USA'),
#  (110, datetime.date(1974, 1, 19), 'employed', 'CA'),
#  (111, datetime.date(1996, 12, 6), 'unemployed', 'UK'),
#  (112, datetime.date(2002, 8, 13), 'unemployed', 'CA'),
#  (113, datetime.date(1970, 7, 13), 'unemployed', 'UK'),
#  (114, datetime.date(1987, 8, 8), 'employed', 'CA'),
#  (115, datetime.date(1981, 5, 7), 'unemployed', 'USA'),
#  (116, datetime.date(1960, 9, 28), 'unemployed', 'USA'),
#  (117, datetime.date(2003, 10, 21), 'unemployed', 'CA'),
#  (118, datetime.date(1988, 1, 11), 'employed', 'CA'),
#  (119, datetime.date(1999, 5, 5), 'employed', 'CA'),
#  (120, datetime.date(1959, 10, 29), 'employed', 'UK'),
#  (121, datetime.date(1961, 6, 11), 'unemployed', 'UK'),
#  (122, datetime.date(2003, 5, 30), 'employed', 'USA'),
#  (123, datetime.date(1970, 8, 23), 'unemployed', 'USA'),
#  (124, datetime.date(1980, 1, 8), 'employed', 'UK'),
#  (125, datetime.date(1972, 4, 8), 'unemployed', 'UK'),
#  (126, datetime.date(1989, 10, 19), 'employed', 'USA'),
#  (127, datetime.date(1984, 10, 26), 'unemployed', 'CA'),
#  (128, datetime.date(1987, 11, 27), 'employed', 'USA'),
#  (129, datetime.date(1977, 6, 2), 'unemployed', 'UK'),
#  (130, datetime.date(2002, 7, 20), 'unemployed', 'UK'),
#  (131, datetime.date(1992, 2, 21), 'employed', 'CA'),
#  (132, datetime.date(1987, 11, 19), 'unemployed', 'CA'),
#  (133, datetime.date(2004, 7, 23), 'unemployed', 'UK'),
#  (134, datetime.date(2004, 6, 14), 'employed', 'CA'),
#  (135, datetime.date(1968, 7, 1), 'employed', 'USA'),
#  (136, datetime.date(1991, 3, 29), 'employed', 'USA'),
#  (137, datetime.date(1980, 10, 7), 'unemployed', 'USA'),
#  (138, datetime.date(1964, 1, 15), 'unemployed', 'UK'),
#  (139, datetime.date(1987, 6, 10), 'employed', 'USA'),
#  (140, datetime.date(1989, 1, 9), 'unemployed', 'UK'),
#  (141, datetime.date(1992, 4, 17), 'unemployed', 'UK'),
#  (142, datetime.date(1973, 12, 5), 'unemployed', 'UK'),
#  (143, datetime.date(1972, 11, 29), 'unemployed', 'USA'),
#  (144, datetime.date(1967, 5, 31), 'employed', 'CA'),
#  (145, datetime.date(1981, 6, 2), 'employed', 'UK'),
#  (146, datetime.date(1958, 5, 29), 'unemployed', 'USA'),
#  (147, datetime.date(1996, 3, 3), 'unemployed', 'USA'),
#  (148, datetime.date(1999, 11, 16), 'employed', 'UK'),
#  (149, datetime.date(1984, 11, 9), 'employed', 'UK'),
#  (150, datetime.date(1980, 11, 15), 'unemployed', 'CA'),
#  (151, datetime.date(1963, 5, 2), 'unemployed', 'USA'),
#  (152, datetime.date(1979, 5, 3), 'unemployed', 'USA'),
#  (153, datetime.date(1960, 1, 29), 'unemployed', 'UK'),
#  (154, datetime.date(1959, 10, 28), 'employed', 'USA'),
#  (155, datetime.date(1973, 12, 14), 'employed', 'CA'),
#  (156, datetime.date(1975, 12, 24), 'unemployed', 'USA'),
#  (157, datetime.date(1997, 10, 19), 'employed', 'USA'),
#  (158, datetime.date(1962, 8, 31), 'unemployed', 'USA'),
#  (159, datetime.date(1963, 10, 5), 'employed', 'UK'),
#  (160, datetime.date(1960, 11, 10), 'employed', 'USA'),
#  (161, datetime.date(1996, 3, 4), 'employed', 'UK'),
#  (162, datetime.date(1995, 1, 11), 'unemployed', 'CA'),
#  (163, datetime.date(2002, 3, 12), 'employed', 'USA'),
#  (164, datetime.date(1987, 8, 31), 'unemployed', 'CA'),
#  (165, datetime.date(1985, 3, 17), 'employed', 'UK'),
#  (166, datetime.date(1955, 9, 22), 'employed', 'CA'),
#  (167, datetime.date(1976, 12, 19), 'unemployed', 'CA'),
#  (168, datetime.date(1958, 10, 23), 'employed', 'CA'),
#  (169, datetime.date(1978, 1, 5), 'employed', 'CA'),
#  (170, datetime.date(1956, 9, 13), 'unemployed', 'CA'),
#  (171, datetime.date(1988, 3, 19), 'employed', 'USA'),
#  (172, datetime.date(1964, 1, 24), 'unemployed', 'USA'),
#  (173, datetime.date(2001, 11, 2), 'employed', 'UK'),
#  (174, datetime.date(1986, 8, 18), 'employed', 'CA'),
#  (175, datetime.date(1983, 5, 3), 'employed', 'CA'),
#  (176, datetime.date(1986, 3, 25), 'employed', 'CA'),
#  (177, datetime.date(2004, 3, 5), 'employed', 'CA'),
#  (178, datetime.date(2005, 2, 27), 'unemployed', 'UK'),
#  (179, datetime.date(1977, 6, 22), 'employed', 'UK'),
#  (180, datetime.date(1972, 5, 6), 'employed', 'UK'),
#  (181, datetime.date(1979, 12, 17), 'employed', 'USA'),
#  (182, datetime.date(1984, 7, 26), 'employed', 'USA'),
#  (183, datetime.date(1982, 11, 10), 'employed', 'USA'),
#  (184, datetime.date(1964, 8, 23), 'employed', 'CA'),
#  (185, datetime.date(1990, 10, 23), 'unemployed', 'CA'),
#  (186, datetime.date(1964, 5, 3), 'unemployed', 'UK'),
#  (187, datetime.date(1987, 3, 31), 'unemployed', 'UK'),
#  (188, datetime.date(1976, 1, 30), 'employed', 'CA'),
#  (189, datetime.date(1969, 8, 22), 'employed', 'UK'),
#  (190, datetime.date(1990, 3, 29), 'unemployed', 'USA'),
#  (191, datetime.date(1963, 7, 11), 'employed', 'UK'),
#  (192, datetime.date(2001, 6, 21), 'unemployed', 'USA'),
#  (193, datetime.date(1962, 6, 17), 'unemployed', 'USA'),
#  (194, datetime.date(1993, 1, 2), 'employed', 'USA'),
#  (195, datetime.date(1980, 11, 1), 'unemployed', 'USA'),
#  (196, datetime.date(1989, 9, 5), 'employed', 'UK'),
#  (197, datetime.date(2002, 6, 3), 'employed', 'UK'),
#  (198, datetime.date(1985, 11, 12), 'unemployed', 'CA'),
#  (199, datetime.date(1955, 6, 2), 'employed', 'UK'),
#  (200, datetime.date(1986, 11, 18), 'unemployed', 'CA'),
#  (201, datetime.date(1990, 4, 2), 'unemployed', 'UK'),
#  (202, datetime.date(1964, 8, 29), 'unemployed', 'CA'),
#  (203, datetime.date(1978, 9, 9), 'employed', 'CA'),
#  (204, datetime.date(1976, 1, 5), 'employed', 'UK'),
#  (205, datetime.date(1993, 7, 10), 'unemployed', 'USA'),
#  (206, datetime.date(1978, 10, 20), 'employed', 'CA'),
#  (207, datetime.date(1971, 5, 10), 'employed', 'UK'),
#  (208, datetime.date(1971, 12, 11), 'employed', 'USA'),
#  (209, datetime.date(1996, 3, 30), 'unemployed', 'USA'),
#  (210, datetime.date(2004, 6, 23), 'employed', 'USA'),
#  (211, datetime.date(1964, 5, 6), 'unemployed', 'USA'),
#  (212, datetime.date(1991, 5, 16), 'employed', 'UK'),
#  (213, datetime.date(1964, 9, 2), 'unemployed', 'CA'),
#  (214, datetime.date(1984, 3, 17), 'unemployed', 'CA'),
#  (215, datetime.date(1969, 5, 24), 'unemployed', 'USA'),
#  (216, datetime.date(1998, 2, 1), 'employed', 'USA'),
#  (217, datetime.date(1982, 7, 7), 'employed', 'UK'),
#  (218, datetime.date(1958, 5, 3), 'unemployed', 'UK'),
#  (219, datetime.date(1997, 9, 24), 'employed', 'USA'),
#  (220, datetime.date(1962, 4, 25), 'unemployed', 'USA'),
#  (221, datetime.date(1963, 10, 2), 'employed', 'UK'),
#  (222, datetime.date(1959, 8, 1), 'unemployed', 'UK'),
#  (223, datetime.date(1989, 12, 20), 'employed', 'USA'),
#  (224, datetime.date(1975, 9, 16), 'unemployed', 'UK'),
#  (225, datetime.date(1971, 6, 9), 'unemployed', 'USA'),
#  (226, datetime.date(1980, 9, 26), 'unemployed', 'CA'),
#  (227, datetime.date(1975, 6, 9), 'employed', 'USA'),
#  (228, datetime.date(1970, 5, 21), 'employed', 'UK'),
#  (229, datetime.date(2003, 4, 9), 'employed', 'CA'),
#  (230, datetime.date(1963, 10, 13), 'unemployed', 'CA'),
#  (231, datetime.date(1985, 8, 30), 'unemployed', 'UK'),
#  (232, datetime.date(2002, 7, 6), 'employed', 'USA'),
#  (233, datetime.date(2001, 9, 9), 'employed', 'USA'),
#  (234, datetime.date(1995, 11, 14), 'employed', 'USA'),
#  (235, datetime.date(1958, 11, 7), 'unemployed', 'CA'),
#  (236, datetime.date(1957, 4, 8), 'unemployed', 'UK'),
#  (237, datetime.date(1983, 8, 25), 'employed', 'UK'),
#  (238, datetime.date(1986, 5, 29), 'unemployed', 'CA'),
#  (239, datetime.date(1995, 6, 2), 'employed', 'USA'),
#  (240, datetime.date(1979, 7, 7), 'employed', 'UK'),
#  (241, datetime.date(1962, 1, 9), 'employed', 'CA'),
#  (242, datetime.date(1958, 7, 8), 'employed', 'USA'),
#  (243, datetime.date(1958, 10, 7), 'employed', 'CA'),
#  (244, datetime.date(1983, 3, 18), 'unemployed', 'USA'),
#  (245, datetime.date(1982, 11, 20), 'unemployed', 'USA'),
#  (246, datetime.date(2004, 12, 14), 'unemployed', 'UK'),
#  (247, datetime.date(1968, 5, 26), 'employed', 'UK'),
#  (248, datetime.date(1968, 2, 10), 'unemployed', 'UK'),
#  (249, datetime.date(1988, 7, 18), 'employed', 'UK'),
#  (250, datetime.date(1960, 7, 18), 'employed', 'UK'),
#  (251, datetime.date(2001, 3, 19), 'employed', 'USA'),
#  (252, datetime.date(1971, 2, 4), 'employed', 'USA'),
#  (253, datetime.date(1990, 1, 1), 'employed', 'CA'),
#  (254, datetime.date(1979, 6, 28), 'unemployed', 'CA'),
#  (255, datetime.date(1955, 12, 31), 'employed', 'USA'),
#  (256, datetime.date(1981, 4, 12), 'employed', 'USA'),
#  (257, datetime.date(1987, 6, 3), 'employed', 'CA'),
#  (258, datetime.date(1964, 8, 24), 'employed', 'CA'),
#  (259, datetime.date(1955, 9, 24), 'unemployed', 'CA'),
#  (260, datetime.date(1958, 5, 31), 'employed', 'CA'),
#  (261, datetime.date(1969, 8, 10), 'employed', 'UK'),
#  (262, datetime.date(1981, 4, 6), 'unemployed', 'CA'),
#  (263, datetime.date(1971, 3, 31), 'employed', 'CA'),
#  (264, datetime.date(1972, 11, 17), 'employed', 'UK'),
#  (265, datetime.date(1969, 4, 9), 'employed', 'UK'),
#  (266, datetime.date(1964, 12, 30), 'employed', 'CA'),
#  (267, datetime.date(1993, 11, 28), 'unemployed', 'USA'),
#  (268, datetime.date(1957, 8, 2), 'unemployed', 'UK'),
#  (269, datetime.date(1999, 8, 4), 'employed', 'CA'),
#  (270, datetime.date(2002, 9, 9), 'unemployed', 'USA'),
#  (271, datetime.date(1966, 5, 15), 'unemployed', 'USA'),
#  (272, datetime.date(1970, 8, 17), 'employed', 'USA'),
#  (273, datetime.date(2005, 2, 22), 'employed', 'USA'),
#  (274, datetime.date(1975, 9, 8), 'employed', 'CA'),
#  (275, datetime.date(1988, 11, 14), 'unemployed', 'UK'),
#  (276, datetime.date(1989, 1, 18), 'employed', 'USA'),
#  (277, datetime.date(1983, 3, 4), 'unemployed', 'USA'),
#  (278, datetime.date(1997, 2, 20), 'employed', 'UK'),
#  (279, datetime.date(1967, 7, 12), 'employed', 'CA'),
#  (280, datetime.date(1979, 9, 6), 'unemployed', 'USA'),
#  (281, datetime.date(1997, 1, 13), 'unemployed', 'USA'),
#  (282, datetime.date(1978, 11, 9), 'employed', 'USA'),
#  (283, datetime.date(1976, 8, 4), 'employed', 'CA'),
#  (284, datetime.date(1971, 1, 27), 'unemployed', 'USA'),
#  (285, datetime.date(1965, 4, 27), 'employed', 'UK'),
#  (286, datetime.date(1997, 12, 22), 'employed', 'USA'),
#  (287, datetime.date(1991, 5, 6), 'employed', 'CA'),
#  (288, datetime.date(1955, 11, 4), 'employed', 'UK'),
#  (289, datetime.date(1956, 3, 12), 'employed', 'UK'),
#  (290, datetime.date(1984, 1, 8), 'employed', 'UK'),
#  (291, datetime.date(1992, 7, 28), 'employed', 'UK'),
#  (292, datetime.date(1970, 8, 14), 'unemployed', 'UK'),
#  (293, datetime.date(1959, 6, 3), 'unemployed', 'CA'),
#  (294, datetime.date(1961, 6, 9), 'unemployed', 'USA'),
#  (295, datetime.date(1981, 5, 15), 'unemployed', 'CA'),
#  (296, datetime.date(1963, 5, 2), 'employed', 'CA'),
#  (297, datetime.date(2004, 8, 25), 'employed', 'UK'),
#  (298, datetime.date(1997, 8, 3), 'unemployed', 'UK'),
#  (299, datetime.date(2004, 8, 16), 'unemployed', 'CA'),
#  (300, datetime.date(1965, 3, 2), 'employed', 'USA')]

# %% [markdown]
# ## Task 2
# <p>You have been informed that there was a problem in the backend system as some of the <code>repayment_channel</code> values are missing. </p>
# <p>The missing values are critical to the analysis so they need to be filled in before proceeding.</p>
# <p>Luckily, they have discovered a pattern in the missing values:</p>
# <ul>
# <li>Repayment higher than 4000 dollars should be made via <code>bank account</code>.</li>
# <li>Repayment lower than 1000 dollars should be made via <code>mail</code>.</li>
# </ul>
# <p>Return the corrected <code>repayment</code> table.</p>

# %%
# %%sql
# postgresql:///lending
#
# -- Keep the two lines above
# -- Start your answers here..
# SELECT
#   repayment_id,
#   loan_id,
#   repayment_date,
#   repayment_amount,
#   CASE
#     WHEN repayment_channel = '-' AND repayment_amount > 4000 THEN 'bank account'
#     WHEN repayment_channel = '-' AND repayment_amount < 1000 THEN 'mail'
#     ELSE repayment_channel
#   END AS repayment_channel
# FROM repayment;
# Out:
# 1500 rows affected.
# [(1, 357, datetime.date(2022, 10, 16), Decimal('1675.83'), 'bank account'),
#  (2, 805, datetime.date(2023, 1, 12), Decimal('867.22'), 'debit card'),
#  (3, 843, datetime.date(2022, 6, 2), Decimal('718.83'), 'phone'),
#  (4, 243, datetime.date(2022, 12, 26), Decimal('1620.97'), 'credit card'),
#  (5, 991, datetime.date(2023, 3, 18), Decimal('2182.17'), 'phone'),
#  (6, 130, datetime.date(2023, 1, 31), Decimal('772.19'), 'mail'),
#  (7, 903, datetime.date(2022, 5, 23), Decimal('1340.22'), 'bank account'),
#  (8, 157, datetime.date(2022, 10, 11), Decimal('1381.22'), 'credit card'),
#  (9, 121, datetime.date(2022, 6, 21), Decimal('1941.47'), 'credit card'),
#  (10, 120, datetime.date(2023, 3, 31), Decimal('410.42'), 'mail'),
#  (11, 408, datetime.date(2023, 2, 28), Decimal('1614.64'), 'bank account'),
#  (12, 483, datetime.date(2022, 11, 28), Decimal('1507.0'), 'bank account'),
#  (13, 584, datetime.date(2022, 5, 16), Decimal('4453.64'), 'mail'),
#  (14, 675, datetime.date(2022, 11, 25), Decimal('2082.17'), 'mail'),
#  (15, 845, datetime.date(2022, 12, 28), Decimal('2406.58'), 'credit card'),
#  (16, 503, datetime.date(2022, 9, 16), Decimal('526.86'), 'debit card'),
#  (17, 947, datetime.date(2022, 11, 18), Decimal('4048.75'), 'phone'),
#  (18, 189, datetime.date(2022, 9, 28), Decimal('1397.17'), 'debit card'),
#  (19, 654, datetime.date(2022, 4, 24), Decimal('281.08'), 'mail'),
#  (20, 323, datetime.date(2023, 2, 15), Decimal('320.19'), 'debit card'),
#  (21, 987, datetime.date(2022, 10, 6), Decimal('2887.94'), 'phone'),
#  (22, 593, datetime.date(2022, 7, 5), Decimal('2854.22'), 'debit card'),
#  (23, 692, datetime.date(2023, 3, 12), Decimal('4188.78'), 'debit card'),
#  (24, 771, datetime.date(2022, 10, 20), Decimal('966.94'), 'mail'),
#  (25, 728, datetime.date(2023, 2, 26), Decimal('1625.78'), 'phone'),
#  (26, 96, datetime.date(2022, 11, 8), Decimal('3118.83'), 'bank account'),
#  (27, 7, datetime.date(2023, 3, 22), Decimal('358.89'), 'mail'),
#  (28, 568, datetime.date(2022, 12, 28), Decimal('2805.58'), 'phone'),
#  (29, 25, datetime.date(2023, 3, 28), Decimal('1477.14'), 'debit card'),
#  (30, 138, datetime.date(2023, 1, 1), Decimal('292.97'), 'mail'),
#  (31, 560, datetime.date(2022, 10, 6), Decimal('614.58'), 'mail'),
#  (32, 264, datetime.date(2022, 9, 2), Decimal('579.44'), 'phone'),
#  (33, 649, datetime.date(2023, 4, 9), Decimal('323.17'), 'bank account'),
#  (34, 591, datetime.date(2022, 12, 24), Decimal('439.94'), 'debit card'),
#  (35, 616, datetime.date(2023, 4, 9), Decimal('322.64'), 'mail'),
#  (36, 97, datetime.date(2023, 1, 6), Decimal('2194.36'), 'debit card'),
#  (37, 853, datetime.date(2023, 3, 22), Decimal('983.83'), 'mail'),
#  (38, 732, datetime.date(2022, 6, 14), Decimal('2652.42'), 'phone'),
#  (39, 144, datetime.date(2022, 6, 21), Decimal('1761.0'), 'debit card'),
#  (40, 935, datetime.date(2023, 2, 22), Decimal('304.5'), 'mail'),
#  (41, 176, datetime.date(2023, 3, 7), Decimal('832.69'), 'mail'),
#  (42, 420, datetime.date(2022, 8, 5), Decimal('2513.61'), 'debit card'),
#  (43, 352, datetime.date(2022, 12, 12), Decimal('2128.75'), 'debit card'),
#  (44, 141, datetime.date(2022, 8, 2), Decimal('938.17'), 'debit card'),
#  (45, 89, datetime.date(2022, 7, 24), Decimal('1698.19'), 'phone'),
#  (46, 253, datetime.date(2022, 11, 15), Decimal('452.44'), 'mail'),
#  (47, 661, datetime.date(2022, 7, 17), Decimal('1022.56'), 'debit card'),
#  (48, 476, datetime.date(2022, 6, 3), Decimal('1954.97'), 'debit card'),
#  (49, 817, datetime.date(2022, 12, 7), Decimal('310.75'), 'phone'),
#  (50, 643, datetime.date(2022, 8, 22), Decimal('929.86'), 'credit card'),
#  (51, 928, datetime.date(2023, 3, 19), Decimal('1813.86'), 'bank account'),
#  (52, 147, datetime.date(2022, 9, 12), Decimal('3208.22'), 'debit card'),
#  (53, 803, datetime.date(2022, 7, 21), Decimal('1403.42'), 'phone'),
#  (54, 271, datetime.date(2022, 4, 17), Decimal('2146.72'), 'bank account'),
#  (55, 666, datetime.date(2023, 3, 9), Decimal('340.47'), 'bank account'),
#  (56, 958, datetime.date(2022, 11, 2), Decimal('812.33'), 'credit card'),
#  (57, 570, datetime.date(2022, 9, 25), Decimal('315.44'), 'credit card'),
#  (58, 973, datetime.date(2023, 4, 14), Decimal('1029.17'), 'debit card'),
#  (59, 625, datetime.date(2022, 8, 26), Decimal('520.42'), 'mail'),
#  (60, 798, datetime.date(2022, 7, 30), Decimal('4314.08'), 'bank account'),
#  (61, 18, datetime.date(2022, 9, 19), Decimal('320.56'), 'debit card'),
#  (62, 164, datetime.date(2022, 5, 11), Decimal('682.64'), 'bank account'),
#  (63, 373, datetime.date(2022, 7, 26), Decimal('1995.03'), 'bank account'),
#  (64, 553, datetime.date(2022, 10, 12), Decimal('2513.42'), 'mail'),
#  (65, 80, datetime.date(2022, 12, 8), Decimal('593.31'), 'credit card'),
#  (66, 685, datetime.date(2022, 9, 7), Decimal('815.67'), 'phone'),
#  (67, 360, datetime.date(2023, 1, 17), Decimal('818.03'), 'credit card'),
#  (68, 988, datetime.date(2022, 12, 25), Decimal('1363.44'), 'mail'),
#  (69, 415, datetime.date(2022, 12, 9), Decimal('5161.56'), 'debit card'),
#  (70, 972, datetime.date(2023, 1, 20), Decimal('770.89'), 'debit card'),
#  (71, 109, datetime.date(2022, 8, 8), Decimal('2482.47'), 'phone'),
#  (72, 204, datetime.date(2022, 8, 10), Decimal('4784.25'), 'mail'),
#  (73, 659, datetime.date(2023, 2, 21), Decimal('2254.28'), 'mail'),
#  (74, 996, datetime.date(2023, 2, 17), Decimal('2515.83'), 'credit card'),
#  (75, 292, datetime.date(2022, 10, 9), Decimal('2245.58'), 'phone'),
#  (76, 466, datetime.date(2022, 7, 17), Decimal('299.31'), 'bank account'),
#  (77, 489, datetime.date(2022, 7, 29), Decimal('2313.69'), 'phone'),
#  (78, 956, datetime.date(2022, 8, 24), Decimal('2024.86'), 'debit card'),
#  (79, 816, datetime.date(2022, 12, 2), Decimal('2397.81'), 'credit card'),
#  (80, 602, datetime.date(2022, 5, 5), Decimal('3086.47'), 'mail'),
#  (81, 177, datetime.date(2022, 6, 5), Decimal('1711.72'), 'bank account'),
#  (82, 304, datetime.date(2022, 9, 28), Decimal('760.83'), 'credit card'),
#  (83, 544, datetime.date(2022, 9, 6), Decimal('419.89'), 'debit card'),
#  (84, 926, datetime.date(2022, 6, 24), Decimal('1042.92'), 'mail'),
#  (85, 557, datetime.date(2023, 1, 2), Decimal('2331.67'), 'credit card'),
#  (86, 985, datetime.date(2022, 6, 21), Decimal('2345.47'), 'mail'),
#  (87, 990, datetime.date(2023, 3, 27), Decimal('2204.56'), 'debit card'),
#  (88, 801, datetime.date(2022, 6, 14), Decimal('523.06'), 'mail'),
#  (89, 399, datetime.date(2022, 8, 25), Decimal('1190.58'), 'credit card'),
#  (90, 671, datetime.date(2023, 1, 7), Decimal('1076.0'), 'debit card'),
#  (91, 480, datetime.date(2022, 11, 16), Decimal('383.17'), 'mail'),
#  (92, 915, datetime.date(2023, 4, 6), Decimal('950.53'), 'mail'),
#  (93, 504, datetime.date(2022, 10, 29), Decimal('1076.75'), 'credit card'),
#  (94, 383, datetime.date(2022, 11, 25), Decimal('726.56'), 'mail'),
#  (95, 33, datetime.date(2022, 7, 18), Decimal('1037.11'), 'bank account'),
#  (96, 864, datetime.date(2022, 11, 29), Decimal('3115.94'), 'debit card'),
#  (97, 23, datetime.date(2022, 12, 21), Decimal('3098.97'), 'bank account'),
#  (98, 188, datetime.date(2022, 5, 11), Decimal('732.75'), 'debit card'),
#  (99, 791, datetime.date(2022, 11, 1), Decimal('1403.19'), 'credit card'),
#  (100, 875, datetime.date(2022, 6, 18), Decimal('4770.33'), 'bank account'),
#  (101, 73, datetime.date(2023, 3, 4), Decimal('2213.33'), 'phone'),
#  (102, 160, datetime.date(2022, 9, 15), Decimal('1889.97'), 'credit card'),
#  (103, 969, datetime.date(2023, 3, 18), Decimal('436.06'), 'mail'),
#  (104, 797, datetime.date(2023, 2, 23), Decimal('727.25'), 'debit card'),
#  (105, 293, datetime.date(2022, 8, 18), Decimal('3522.53'), 'phone'),
#  (106, 766, datetime.date(2022, 10, 2), Decimal('524.31'), 'phone'),
#  (107, 289, datetime.date(2023, 3, 13), Decimal('1942.81'), 'phone'),
#  (108, 84, datetime.date(2022, 10, 23), Decimal('1086.67'), 'credit card'),
#  (109, 267, datetime.date(2023, 4, 6), Decimal('1713.72'), 'phone'),
#  (110, 198, datetime.date(2022, 5, 22), Decimal('335.69'), 'debit card'),
#  (111, 410, datetime.date(2022, 6, 20), Decimal('711.44'), 'mail'),
#  (112, 807, datetime.date(2022, 12, 3), Decimal('665.31'), 'bank account'),
#  (113, 825, datetime.date(2022, 4, 20), Decimal('682.86'), 'mail'),
#  (114, 229, datetime.date(2023, 1, 12), Decimal('3570.47'), 'phone'),
#  (115, 56, datetime.date(2022, 11, 1), Decimal('1438.44'), 'phone'),
#  (116, 559, datetime.date(2022, 12, 21), Decimal('655.36'), 'mail'),
#  (117, 550, datetime.date(2022, 9, 4), Decimal('381.92'), 'phone'),
#  (118, 392, datetime.date(2022, 7, 7), Decimal('1961.22'), 'phone'),
#  (119, 361, datetime.date(2022, 8, 21), Decimal('1622.56'), 'debit card'),
#  (120, 16, datetime.date(2022, 5, 10), Decimal('1515.83'), 'debit card'),
#  (121, 461, datetime.date(2022, 6, 1), Decimal('1152.53'), 'phone'),
#  (122, 810, datetime.date(2023, 4, 13), Decimal('1397.5'), 'phone'),
#  (123, 604, datetime.date(2023, 4, 4), Decimal('695.58'), 'mail'),
#  (124, 362, datetime.date(2022, 11, 27), Decimal('616.56'), 'phone'),
#  (125, 368, datetime.date(2022, 11, 23), Decimal('1334.03'), 'phone'),
#  (126, 221, datetime.date(2022, 11, 15), Decimal('1904.89'), 'credit card'),
#  (127, 60, datetime.date(2022, 12, 2), Decimal('1040.03'), 'debit card'),
#  (128, 59, datetime.date(2022, 9, 30), Decimal('380.19'), 'bank account'),
#  (129, 273, datetime.date(2023, 3, 8), Decimal('1016.72'), 'mail'),
#  (130, 42, datetime.date(2022, 12, 17), Decimal('399.17'), 'mail'),
#  (131, 586, datetime.date(2022, 11, 9), Decimal('303.42'), 'mail'),
#  (132, 723, datetime.date(2022, 10, 30), Decimal('289.31'), 'bank account'),
#  (133, 213, datetime.date(2023, 1, 28), Decimal('1975.64'), 'credit card'),
#  (134, 599, datetime.date(2022, 12, 26), Decimal('603.81'), 'debit card'),
#  (135, 460, datetime.date(2022, 11, 27), Decimal('283.61'), 'bank account'),
#  (136, 9, datetime.date(2022, 5, 4), Decimal('1643.75'), 'bank account'),
#  (137, 394, datetime.date(2022, 10, 16), Decimal('363.69'), 'bank account'),
#  (138, 670, datetime.date(2022, 5, 22), Decimal('1916.17'), 'debit card'),
#  (139, 764, datetime.date(2022, 11, 2), Decimal('356.42'), 'debit card'),
#  (140, 618, datetime.date(2023, 1, 17), Decimal('3304.17'), 'credit card'),
#  (141, 769, datetime.date(2022, 10, 13), Decimal('2407.17'), 'mail'),
#  (142, 370, datetime.date(2022, 6, 3), Decimal('1905.64'), 'bank account'),
#  (143, 804, datetime.date(2023, 4, 15), Decimal('1048.69'), 'bank account'),
#  (144, 868, datetime.date(2023, 3, 12), Decimal('670.67'), 'phone'),
#  (145, 554, datetime.date(2023, 2, 5), Decimal('3253.72'), 'bank account'),
#  (146, 989, datetime.date(2022, 5, 16), Decimal('1351.97'), 'mail'),
#  (147, 885, datetime.date(2023, 4, 6), Decimal('387.64'), 'mail'),
#  (148, 380, datetime.date(2023, 2, 2), Decimal('370.83'), 'phone'),
#  (149, 447, datetime.date(2022, 11, 4), Decimal('900.94'), 'credit card'),
#  (150, 115, datetime.date(2023, 3, 1), Decimal('344.53'), 'credit card'),
#  (151, 835, datetime.date(2022, 8, 9), Decimal('2560.75'), 'bank account'),
#  (152, 457, datetime.date(2022, 8, 1), Decimal('473.58'), 'credit card'),
#  (153, 344, datetime.date(2023, 2, 26), Decimal('2127.89'), 'mail'),
#  (154, 333, datetime.date(2022, 12, 12), Decimal('4640.03'), 'phone'),
#  (155, 607, datetime.date(2023, 4, 8), Decimal('3972.0'), 'credit card'),
#  (156, 920, datetime.date(2023, 2, 8), Decimal('1609.33'), 'debit card'),
#  (157, 941, datetime.date(2022, 4, 29), Decimal('319.25'), 'credit card'),
#  (158, 28, datetime.date(2022, 12, 25), Decimal('465.5'), 'bank account'),
#  (159, 284, datetime.date(2023, 3, 8), Decimal('4632.0'), 'debit card'),
#  (160, 918, datetime.date(2022, 10, 9), Decimal('1625.64'), 'debit card'),
#  (161, 435, datetime.date(2022, 7, 11), Decimal('910.08'), 'debit card'),
#  (162, 150, datetime.date(2022, 6, 5), Decimal('3289.92'), 'debit card'),
#  (163, 748, datetime.date(2022, 12, 5), Decimal('1288.31'), 'debit card'),
#  (164, 874, datetime.date(2023, 1, 1), Decimal('3450.11'), 'mail'),
#  (165, 61, datetime.date(2022, 6, 18), Decimal('738.42'), 'phone'),
#  (166, 275, datetime.date(2022, 11, 30), Decimal('2238.67'), 'phone'),
#  (167, 265, datetime.date(2022, 5, 1), Decimal('1527.56'), 'credit card'),
#  (168, 857, datetime.date(2022, 11, 12), Decimal('1544.47'), 'mail'),
#  (169, 704, datetime.date(2022, 4, 20), Decimal('899.5'), 'debit card'),
#  (170, 458, datetime.date(2022, 12, 8), Decimal('659.11'), 'mail'),
#  (171, 727, datetime.date(2022, 10, 2), Decimal('509.31'), 'mail'),
#  (172, 776, datetime.date(2022, 11, 17), Decimal('801.47'), 'mail'),
#  (173, 761, datetime.date(2022, 11, 1), Decimal('3404.75'), 'phone'),
#  (174, 487, datetime.date(2022, 6, 29), Decimal('961.47'), 'phone'),
#  (175, 346, datetime.date(2022, 6, 23), Decimal('3293.17'), 'debit card'),
#  (176, 549, datetime.date(2022, 12, 26), Decimal('1198.28'), 'mail'),
#  (177, 50, datetime.date(2023, 2, 11), Decimal('462.72'), 'credit card'),
#  (178, 294, datetime.date(2022, 6, 21), Decimal('282.31'), 'credit card'),
#  (179, 148, datetime.date(2023, 1, 18), Decimal('3133.03'), 'bank account'),
#  (180, 930, datetime.date(2022, 7, 27), Decimal('568.22'), 'mail'),
#  (181, 820, datetime.date(2022, 8, 13), Decimal('2595.17'), 'bank account'),
#  (182, 942, datetime.date(2022, 4, 16), Decimal('2041.64'), 'debit card'),
#  (183, 156, datetime.date(2023, 3, 26), Decimal('1190.39'), 'phone'),
#  (184, 619, datetime.date(2022, 5, 23), Decimal('718.97'), 'credit card'),
#  (185, 538, datetime.date(2023, 2, 26), Decimal('1415.08'), 'mail'),
#  (186, 872, datetime.date(2023, 3, 11), Decimal('293.17'), 'mail'),
#  (187, 834, datetime.date(2023, 3, 7), Decimal('4620.75'), 'mail'),
#  (188, 531, datetime.date(2022, 11, 16), Decimal('401.97'), 'bank account'),
#  (189, 159, datetime.date(2023, 2, 11), Decimal('568.17'), 'credit card'),
#  (190, 306, datetime.date(2023, 3, 30), Decimal('376.58'), 'mail'),
#  (191, 620, datetime.date(2022, 5, 9), Decimal('1224.44'), 'phone'),
#  (192, 515, datetime.date(2023, 3, 4), Decimal('4710.39'), 'mail'),
#  (193, 83, datetime.date(2023, 1, 1), Decimal('344.72'), 'mail'),
#  (194, 378, datetime.date(2023, 3, 23), Decimal('948.64'), 'phone'),
#  (195, 3, datetime.date(2022, 6, 18), Decimal('377.64'), 'credit card'),
#  (196, 381, datetime.date(2022, 9, 20), Decimal('1560.89'), 'mail'),
#  (197, 431, datetime.date(2022, 6, 29), Decimal('3901.78'), 'debit card'),
#  (198, 254, datetime.date(2022, 12, 29), Decimal('2117.67'), 'credit card'),
#  (199, 970, datetime.date(2022, 8, 5), Decimal('2370.92'), 'phone'),
#  (200, 725, datetime.date(2023, 1, 16), Decimal('3573.81'), 'credit card'),
#  (201, 94, datetime.date(2022, 10, 15), Decimal('658.31'), 'mail'),
#  (202, 755, datetime.date(2022, 4, 25), Decimal('2177.47'), 'credit card'),
#  (203, 708, datetime.date(2022, 12, 25), Decimal('1496.81'), 'debit card'),
#  (204, 240, datetime.date(2022, 5, 18), Decimal('363.19'), 'mail'),
#  (205, 172, datetime.date(2023, 3, 19), Decimal('2118.89'), 'credit card'),
#  (206, 450, datetime.date(2023, 1, 9), Decimal('1369.64'), 'bank account'),
#  (207, 823, datetime.date(2022, 11, 22), Decimal('329.78'), 'mail'),
#  (208, 697, datetime.date(2022, 11, 1), Decimal('1200.44'), 'debit card'),
#  (209, 768, datetime.date(2022, 5, 17), Decimal('1494.53'), 'mail'),
#  (210, 754, datetime.date(2023, 1, 21), Decimal('574.47'), 'mail'),
#  (211, 717, datetime.date(2023, 2, 11), Decimal('2824.03'), 'bank account'),
#  (212, 933, datetime.date(2022, 6, 6), Decimal('2658.11'), 'bank account'),
#  (213, 128, datetime.date(2022, 5, 7), Decimal('404.14'), 'mail'),
#  (214, 479, datetime.date(2023, 1, 22), Decimal('589.39'), 'phone'),
#  (215, 505, datetime.date(2022, 9, 7), Decimal('2205.19'), 'mail'),
#  (216, 453, datetime.date(2022, 9, 24), Decimal('4685.14'), 'credit card'),
#  (217, 968, datetime.date(2023, 1, 7), Decimal('579.61'), 'debit card'),
#  (218, 51, datetime.date(2022, 12, 10), Decimal('2196.25'), 'bank account'),
#  (219, 47, datetime.date(2022, 8, 20), Decimal('1596.81'), 'mail'),
#  (220, 347, datetime.date(2023, 1, 19), Decimal('320.69'), 'debit card'),
#  (221, 715, datetime.date(2023, 1, 28), Decimal('2712.72'), 'mail'),
#  (222, 251, datetime.date(2022, 6, 27), Decimal('1797.56'), 'phone'),
#  (223, 181, datetime.date(2022, 9, 21), Decimal('1405.94'), 'credit card'),
#  (224, 19, datetime.date(2022, 7, 25), Decimal('2648.69'), 'mail'),
#  (225, 165, datetime.date(2023, 2, 19), Decimal('2946.94'), 'credit card'),
#  (226, 215, datetime.date(2022, 11, 18), Decimal('833.22'), 'mail'),
#  (227, 123, datetime.date(2022, 8, 15), Decimal('2326.03'), 'credit card'),
#  (228, 463, datetime.date(2022, 10, 11), Decimal('3292.5'), 'credit card'),
#  (229, 757, datetime.date(2022, 10, 29), Decimal('409.22'), 'mail'),
#  (230, 133, datetime.date(2023, 3, 22), Decimal('1701.83'), 'credit card'),
#  (231, 149, datetime.date(2023, 2, 18), Decimal('738.56'), 'mail'),
#  (232, 529, datetime.date(2022, 11, 18), Decimal('3338.33'), 'debit card'),
#  (233, 486, datetime.date(2022, 11, 24), Decimal('2567.72'), 'phone'),
#  (234, 645, datetime.date(2022, 10, 4), Decimal('420.25'), 'mail'),
#  (235, 759, datetime.date(2022, 10, 9), Decimal('605.58'), 'bank account'),
#  (236, 516, datetime.date(2022, 11, 25), Decimal('284.08'), 'mail'),
#  (237, 821, datetime.date(2022, 7, 17), Decimal('1648.86'), 'debit card'),
#  (238, 107, datetime.date(2023, 2, 14), Decimal('1434.19'), 'credit card'),
#  (239, 472, datetime.date(2023, 2, 25), Decimal('966.47'), 'phone'),
#  (240, 456, datetime.date(2022, 10, 26), Decimal('453.83'), 'bank account'),
#  (241, 682, datetime.date(2022, 6, 21), Decimal('1573.64'), 'credit card'),
#  (242, 815, datetime.date(2022, 8, 15), Decimal('329.92'), 'phone'),
#  (243, 995, datetime.date(2023, 1, 26), Decimal('1792.58'), 'phone'),
#  (244, 513, datetime.date(2023, 3, 10), Decimal('1573.81'), 'credit card'),
#  (245, 838, datetime.date(2022, 8, 15), Decimal('2313.22'), 'credit card'),
#  (246, 345, datetime.date(2022, 12, 28), Decimal('2126.36'), 'debit card'),
#  (247, 778, datetime.date(2022, 9, 26), Decimal('480.33'), 'mail'),
#  (248, 38, datetime.date(2022, 5, 22), Decimal('1872.17'), 'phone'),
#  (249, 724, datetime.date(2022, 7, 5), Decimal('1175.25'), 'bank account'),
#  (250, 216, datetime.date(2022, 5, 13), Decimal('279.25'), 'debit card'),
#  (251, 129, datetime.date(2022, 9, 26), Decimal('1160.83'), 'mail'),
#  (252, 137, datetime.date(2023, 4, 10), Decimal('502.14'), 'bank account'),
#  (253, 668, datetime.date(2023, 2, 3), Decimal('3325.47'), 'credit card'),
#  (254, 547, datetime.date(2023, 1, 4), Decimal('3991.42'), 'debit card'),
#  (255, 122, datetime.date(2022, 6, 20), Decimal('686.56'), 'mail'),
#  (256, 63, datetime.date(2022, 5, 5), Decimal('2322.78'), 'mail'),
#  (257, 828, datetime.date(2023, 3, 11), Decimal('3695.81'), 'debit card'),
#  (258, 246, datetime.date(2022, 7, 22), Decimal('2476.83'), 'credit card'),
#  (259, 895, datetime.date(2023, 1, 13), Decimal('352.22'), 'phone'),
#  (260, 876, datetime.date(2022, 6, 7), Decimal('1049.11'), 'debit card'),
#  (261, 296, datetime.date(2022, 6, 7), Decimal('1290.42'), 'mail'),
#  (262, 610, datetime.date(2022, 4, 23), Decimal('1993.56'), 'debit card'),
#  (263, 811, datetime.date(2022, 6, 9), Decimal('280.69'), 'mail'),
#  (264, 894, datetime.date(2022, 5, 11), Decimal('3415.72'), 'debit card'),
#  (265, 372, datetime.date(2022, 11, 15), Decimal('433.39'), 'debit card'),
#  (266, 695, datetime.date(2022, 11, 18), Decimal('2438.25'), 'bank account'),
#  (267, 295, datetime.date(2022, 6, 12), Decimal('1013.14'), 'bank account'),
#  (268, 105, datetime.date(2022, 6, 25), Decimal('343.47'), 'debit card'),
#  (269, 218, datetime.date(2023, 2, 18), Decimal('2378.5'), 'phone'),
#  (270, 545, datetime.date(2022, 11, 9), Decimal('1875.56'), 'phone'),
#  (271, 982, datetime.date(2022, 10, 19), Decimal('440.08'), 'phone'),
#  (272, 39, datetime.date(2023, 1, 18), Decimal('1150.44'), 'bank account'),
#  (273, 185, datetime.date(2022, 5, 25), Decimal('600.47'), 'mail'),
#  (274, 579, datetime.date(2022, 7, 12), Decimal('1508.47'), 'credit card'),
#  (275, 442, datetime.date(2022, 6, 8), Decimal('1190.06'), 'mail'),
#  (276, 924, datetime.date(2023, 3, 20), Decimal('2363.64'), 'debit card'),
#  (277, 832, datetime.date(2022, 10, 17), Decimal('735.08'), 'mail'),
#  (278, 173, datetime.date(2022, 8, 3), Decimal('1388.64'), 'phone'),
#  (279, 192, datetime.date(2022, 10, 18), Decimal('1259.89'), 'mail'),
#  (280, 934, datetime.date(2023, 3, 31), Decimal('802.08'), 'phone'),
#  (281, 136, datetime.date(2022, 7, 29), Decimal('3666.67'), 'credit card'),
#  (282, 87, datetime.date(2022, 6, 13), Decimal('919.42'), 'credit card'),
#  (283, 609, datetime.date(2023, 1, 22), Decimal('1431.14'), 'credit card'),
#  (284, 630, datetime.date(2022, 9, 28), Decimal('626.5'), 'phone'),
#  (285, 492, datetime.date(2022, 12, 1), Decimal('1138.94'), 'debit card'),
#  (286, 62, datetime.date(2022, 10, 18), Decimal('955.39'), 'mail'),
#  (287, 542, datetime.date(2022, 6, 25), Decimal('1322.22'), 'mail'),
#  (288, 660, datetime.date(2022, 11, 16), Decimal('564.08'), 'phone'),
#  (289, 424, datetime.date(2023, 4, 11), Decimal('1413.06'), 'bank account'),
#  (290, 186, datetime.date(2023, 1, 14), Decimal('404.19'), 'phone'),
#  (291, 282, datetime.date(2022, 12, 29), Decimal('1112.42'), 'credit card'),
#  (292, 168, datetime.date(2022, 4, 30), Decimal('465.42'), 'mail'),
#  (293, 421, datetime.date(2022, 9, 13), Decimal('5029.11'), 'phone'),
#  (294, 365, datetime.date(2023, 3, 17), Decimal('880.5'), 'credit card'),
#  (295, 8, datetime.date(2022, 11, 29), Decimal('295.53'), 'bank account'),
#  (296, 694, datetime.date(2022, 8, 21), Decimal('351.0'), 'credit card'),
#  (297, 459, datetime.date(2022, 8, 8), Decimal('3745.06'), 'mail'),
#  (298, 397, datetime.date(2022, 10, 29), Decimal('305.44'), 'mail'),
#  (299, 846, datetime.date(2022, 8, 23), Decimal('1016.69'), 'credit card'),
#  (300, 237, datetime.date(2022, 7, 12), Decimal('2969.61'), 'phone'),
#  (301, 878, datetime.date(2022, 10, 1), Decimal('652.14'), 'mail'),
#  (302, 974, datetime.date(2022, 6, 27), Decimal('4314.67'), 'bank account'),
#  (303, 226, datetime.date(2023, 3, 31), Decimal('1641.75'), 'credit card'),
#  (304, 474, datetime.date(2022, 12, 20), Decimal('1016.64'), 'bank account'),
#  (305, 29, datetime.date(2022, 10, 10), Decimal('1294.19'), 'mail'),
#  (306, 792, datetime.date(2022, 5, 21), Decimal('4344.25'), 'bank account'),
#  (307, 231, datetime.date(2022, 5, 18), Decimal('1120.42'), 'debit card'),
#  (308, 100, datetime.date(2023, 2, 11), Decimal('1586.0'), 'credit card'),
#  (309, 118, datetime.date(2023, 1, 12), Decimal('2986.58'), 'credit card'),
#  (310, 337, datetime.date(2022, 6, 14), Decimal('1955.75'), 'credit card'),
#  (311, 963, datetime.date(2022, 8, 6), Decimal('1942.42'), 'credit card'),
#  (312, 712, datetime.date(2022, 5, 17), Decimal('3324.42'), 'debit card'),
#  (313, 500, datetime.date(2022, 7, 2), Decimal('1014.31'), 'mail'),
#  (314, 332, datetime.date(2022, 6, 14), Decimal('582.83'), 'debit card'),
#  (315, 145, datetime.date(2022, 11, 16), Decimal('1902.28'), 'phone'),
#  (316, 281, datetime.date(2022, 4, 16), Decimal('4298.58'), 'bank account'),
#  (317, 913, datetime.date(2022, 7, 12), Decimal('3739.47'), 'debit card'),
#  (318, 468, datetime.date(2023, 3, 1), Decimal('3825.08'), 'mail'),
#  (319, 851, datetime.date(2023, 2, 28), Decimal('2627.14'), 'phone'),
#  (320, 313, datetime.date(2022, 9, 4), Decimal('524.33'), 'bank account'),
#  (321, 407, datetime.date(2022, 9, 30), Decimal('1937.69'), 'bank account'),
#  (322, 428, datetime.date(2022, 8, 22), Decimal('370.14'), 'credit card'),
#  (323, 635, datetime.date(2023, 3, 25), Decimal('1442.83'), 'debit card'),
#  (324, 134, datetime.date(2023, 3, 25), Decimal('2493.36'), 'bank account'),
#  (325, 867, datetime.date(2023, 2, 11), Decimal('1446.36'), 'phone'),
#  (326, 379, datetime.date(2022, 9, 4), Decimal('304.31'), 'mail'),
#  (327, 242, datetime.date(2022, 10, 1), Decimal('1013.75'), 'debit card'),
#  (328, 581, datetime.date(2023, 3, 10), Decimal('2849.36'), 'phone'),
#  (329, 142, datetime.date(2023, 3, 6), Decimal('2426.06'), 'bank account'),
#  (330, 184, datetime.date(2022, 7, 23), Decimal('3500.78'), 'credit card'),
#  (331, 418, datetime.date(2022, 12, 26), Decimal('3164.97'), 'mail'),
#  (332, 235, datetime.date(2022, 6, 19), Decimal('471.69'), 'phone'),
#  (333, 277, datetime.date(2022, 4, 24), Decimal('1985.0'), 'mail'),
#  (334, 48, datetime.date(2022, 7, 8), Decimal('3361.44'), 'phone'),
#  (335, 195, datetime.date(2022, 7, 10), Decimal('2862.36'), 'bank account'),
#  (336, 499, datetime.date(2022, 10, 21), Decimal('2515.86'), 'debit card'),
#  (337, 678, datetime.date(2023, 1, 20), Decimal('1103.69'), 'phone'),
#  (338, 965, datetime.date(2023, 1, 21), Decimal('2954.75'), 'phone'),
#  (339, 626, datetime.date(2022, 8, 30), Decimal('1247.03'), 'phone'),
#  (340, 496, datetime.date(2022, 4, 27), Decimal('1727.75'), 'debit card'),
#  (341, 634, datetime.date(2023, 1, 14), Decimal('617.28'), 'bank account'),
#  (342, 971, datetime.date(2022, 7, 26), Decimal('3977.25'), 'bank account'),
#  (343, 954, datetime.date(2022, 6, 27), Decimal('754.83'), 'phone'),
#  (344, 687, datetime.date(2023, 1, 14), Decimal('2844.72'), 'bank account'),
#  (345, 818, datetime.date(2023, 1, 5), Decimal('5247.42'), 'mail'),
#  (346, 263, datetime.date(2022, 9, 23), Decimal('2612.72'), 'credit card'),
#  (347, 112, datetime.date(2022, 7, 9), Decimal('3911.64'), 'phone'),
#  (348, 454, datetime.date(2023, 3, 4), Decimal('3067.08'), 'bank account'),
#  (349, 214, datetime.date(2022, 11, 26), Decimal('1897.08'), 'debit card'),
#  (350, 819, datetime.date(2022, 10, 16), Decimal('306.56'), 'mail'),
#  (351, 182, datetime.date(2022, 5, 13), Decimal('2551.0'), 'debit card'),
#  (352, 207, datetime.date(2022, 7, 13), Decimal('3253.14'), 'credit card'),
#  (353, 986, datetime.date(2023, 1, 31), Decimal('1691.19'), 'mail'),
#  (354, 297, datetime.date(2022, 9, 3), Decimal('915.75'), 'credit card'),
#  (355, 839, datetime.date(2022, 11, 24), Decimal('2707.28'), 'debit card'),
#  (356, 916, datetime.date(2022, 7, 3), Decimal('442.58'), 'phone'),
#  (357, 540, datetime.date(2023, 2, 6), Decimal('279.53'), 'mail'),
#  (358, 170, datetime.date(2022, 7, 14), Decimal('1831.78'), 'debit card'),
#  (359, 760, datetime.date(2022, 7, 13), Decimal('1394.86'), 'bank account'),
#  (360, 631, datetime.date(2022, 11, 18), Decimal('582.22'), 'mail'),
#  (361, 901, datetime.date(2022, 7, 25), Decimal('1278.83'), 'debit card'),
#  (362, 794, datetime.date(2023, 2, 19), Decimal('1947.47'), 'bank account'),
#  (363, 252, datetime.date(2023, 3, 8), Decimal('307.39'), 'mail'),
#  (364, 11, datetime.date(2023, 4, 1), Decimal('705.61'), 'mail'),
#  (365, 241, datetime.date(2023, 1, 31), Decimal('706.64'), 'bank account'),
#  (366, 633, datetime.date(2022, 10, 1), Decimal('1025.64'), 'phone'),
#  (367, 367, datetime.date(2022, 6, 29), Decimal('438.19'), 'mail'),
#  (368, 175, datetime.date(2022, 8, 20), Decimal('1618.53'), 'credit card'),
#  (369, 730, datetime.date(2022, 12, 1), Decimal('1613.42'), 'credit card'),
#  (370, 789, datetime.date(2022, 11, 15), Decimal('844.33'), 'bank account'),
#  (371, 524, datetime.date(2023, 1, 18), Decimal('278.33'), 'bank account'),
#  (372, 46, datetime.date(2022, 6, 18), Decimal('1317.67'), 'debit card'),
#  (373, 802, datetime.date(2023, 3, 12), Decimal('681.14'), 'phone'),
#  (374, 490, datetime.date(2022, 6, 16), Decimal('665.11'), 'bank account'),
#  (375, 327, datetime.date(2022, 12, 22), Decimal('3192.08'), 'debit card'),
#  (376, 334, datetime.date(2022, 4, 18), Decimal('3474.75'), 'credit card'),
#  (377, 270, datetime.date(2023, 3, 27), Decimal('3011.47'), 'phone'),
#  (378, 592, datetime.date(2022, 10, 11), Decimal('2411.47'), 'mail'),
#  (379, 881, datetime.date(2022, 4, 22), Decimal('1113.42'), 'bank account'),
#  (380, 706, datetime.date(2022, 12, 21), Decimal('694.08'), 'phone'),
#  (381, 127, datetime.date(2022, 12, 6), Decimal('2474.44'), 'bank account'),
#  (382, 664, datetime.date(2022, 5, 15), Decimal('549.11'), 'phone'),
#  (383, 674, datetime.date(2022, 6, 8), Decimal('2350.0'), 'mail'),
#  (384, 76, datetime.date(2022, 6, 19), Decimal('296.11'), 'mail'),
#  (385, 303, datetime.date(2022, 5, 9), Decimal('577.75'), 'mail'),
#  (386, 775, datetime.date(2022, 6, 14), Decimal('694.97'), 'mail'),
#  (387, 565, datetime.date(2023, 2, 24), Decimal('436.25'), 'credit card'),
#  (388, 403, datetime.date(2023, 1, 28), Decimal('3520.92'), 'debit card'),
#  (389, 49, datetime.date(2022, 4, 20), Decimal('434.33'), 'phone'),
#  (390, 32, datetime.date(2023, 4, 5), Decimal('1407.5'), 'bank account'),
#  (391, 552, datetime.date(2023, 2, 8), Decimal('1640.42'), 'credit card'),
#  (392, 321, datetime.date(2022, 5, 10), Decimal('2126.28'), 'credit card'),
#  (393, 562, datetime.date(2023, 2, 27), Decimal('2107.31'), 'bank account'),
#  (394, 863, datetime.date(2022, 6, 5), Decimal('3045.0'), 'debit card'),
#  (395, 962, datetime.date(2022, 7, 20), Decimal('2060.36'), 'phone'),
#  (396, 151, datetime.date(2023, 3, 25), Decimal('3507.67'), 'bank account'),
#  (397, 328, datetime.date(2022, 6, 30), Decimal('499.39'), 'bank account'),
#  (398, 922, datetime.date(2022, 4, 26), Decimal('3277.56'), 'debit card'),
#  (399, 713, datetime.date(2023, 2, 13), Decimal('1548.81'), 'debit card'),
#  (400, 518, datetime.date(2023, 1, 27), Decimal('391.64'), 'debit card'),
#  (401, 508, datetime.date(2023, 3, 17), Decimal('585.56'), 'mail'),
#  (402, 481, datetime.date(2022, 4, 17), Decimal('1700.31'), 'debit card'),
#  (403, 220, datetime.date(2023, 2, 18), Decimal('335.86'), 'credit card'),
#  (404, 452, datetime.date(2023, 2, 23), Decimal('3481.11'), 'bank account'),
#  (405, 736, datetime.date(2023, 1, 16), Decimal('731.89'), 'debit card'),
#  (406, 525, datetime.date(2022, 12, 2), Decimal('1263.11'), 'credit card'),
#  (407, 672, datetime.date(2023, 4, 12), Decimal('425.69'), 'debit card'),
#  (408, 976, datetime.date(2022, 12, 17), Decimal('1856.14'), 'debit card'),
#  (409, 606, datetime.date(2023, 1, 25), Decimal('4535.36'), 'bank account'),
#  (410, 316, datetime.date(2022, 10, 19), Decimal('2265.08'), 'credit card'),
#  (411, 601, datetime.date(2023, 2, 4), Decimal('2722.58'), 'phone'),
#  (412, 774, datetime.date(2022, 9, 20), Decimal('1663.39'), 'bank account'),
#  (413, 66, datetime.date(2022, 8, 26), Decimal('2694.53'), 'debit card'),
#  (414, 734, datetime.date(2022, 7, 2), Decimal('332.28'), 'mail'),
#  (415, 432, datetime.date(2023, 2, 8), Decimal('1066.67'), 'debit card'),
#  (416, 187, datetime.date(2022, 11, 10), Decimal('791.72'), 'mail'),
#  (417, 699, datetime.date(2023, 1, 10), Decimal('2083.14'), 'mail'),
#  (418, 426, datetime.date(2022, 5, 16), Decimal('1343.94'), 'credit card'),
#  (419, 102, datetime.date(2023, 3, 18), Decimal('4297.64'), 'phone'),
#  (420, 770, datetime.date(2022, 12, 29), Decimal('763.33'), 'phone'),
#  (421, 290, datetime.date(2022, 6, 8), Decimal('972.33'), 'credit card'),
#  (422, 72, datetime.date(2023, 1, 5), Decimal('1030.47'), 'phone'),
#  (423, 806, datetime.date(2022, 8, 19), Decimal('508.56'), 'bank account'),
#  (424, 376, datetime.date(2022, 6, 16), Decimal('1819.44'), 'mail'),
#  (425, 611, datetime.date(2022, 11, 22), Decimal('370.42'), 'credit card'),
#  (426, 178, datetime.date(2023, 4, 13), Decimal('419.61'), 'credit card'),
#  (427, 532, datetime.date(2022, 8, 1), Decimal('1295.61'), 'bank account'),
#  (428, 230, datetime.date(2022, 9, 1), Decimal('279.67'), 'mail'),
#  (429, 319, datetime.date(2022, 5, 9), Decimal('1212.47'), 'phone'),
#  (430, 873, datetime.date(2023, 2, 1), Decimal('441.58'), 'bank account'),
#  (431, 689, datetime.date(2022, 6, 23), Decimal('1085.5'), 'phone'),
#  (432, 310, datetime.date(2023, 4, 6), Decimal('358.06'), 'phone'),
#  (433, 613, datetime.date(2022, 11, 2), Decimal('340.64'), 'credit card'),
#  (434, 386, datetime.date(2023, 3, 9), Decimal('633.25'), 'mail'),
#  (435, 658, datetime.date(2022, 9, 25), Decimal('1484.42'), 'bank account'),
#  (436, 520, datetime.date(2023, 4, 5), Decimal('1510.22'), 'phone'),
#  (437, 710, datetime.date(2022, 7, 22), Decimal('1722.72'), 'phone'),
#  (438, 285, datetime.date(2022, 9, 22), Decimal('2256.56'), 'debit card'),
#  (439, 467, datetime.date(2022, 11, 24), Decimal('303.0'), 'mail'),
#  (440, 906, datetime.date(2023, 2, 17), Decimal('4720.58'), 'bank account'),
#  (441, 563, datetime.date(2022, 8, 23), Decimal('1039.89'), 'credit card'),
#  (442, 783, datetime.date(2023, 1, 28), Decimal('386.78'), 'phone'),
#  (443, 957, datetime.date(2022, 8, 24), Decimal('278.64'), 'mail'),
#  (444, 722, datetime.date(2022, 4, 23), Decimal('434.69'), 'phone'),
#  (445, 814, datetime.date(2022, 12, 24), Decimal('2137.06'), 'credit card'),
#  (446, 753, datetime.date(2022, 10, 13), Decimal('721.67'), 'mail'),
#  (447, 786, datetime.date(2022, 10, 30), Decimal('832.64'), 'mail'),
#  (448, 940, datetime.date(2022, 10, 18), Decimal('855.11'), 'credit card'),
#  (449, 623, datetime.date(2022, 5, 21), Decimal('282.56'), 'credit card'),
#  (450, 884, datetime.date(2022, 7, 6), Decimal('890.33'), 'mail'),
#  (451, 261, datetime.date(2022, 4, 27), Decimal('4505.11'), 'phone'),
#  (452, 510, datetime.date(2022, 9, 18), Decimal('2121.33'), 'mail'),
#  (453, 419, datetime.date(2022, 5, 15), Decimal('299.42'), 'mail'),
#  (454, 624, datetime.date(2023, 3, 28), Decimal('840.67'), 'phone'),
#  (455, 567, datetime.date(2022, 5, 28), Decimal('3064.89'), 'credit card'),
#  (456, 556, datetime.date(2023, 3, 26), Decimal('1754.44'), 'mail'),
#  (457, 338, datetime.date(2022, 5, 22), Decimal('2317.92'), 'phone'),
#  (458, 455, datetime.date(2022, 8, 28), Decimal('2242.89'), 'credit card'),
#  (459, 644, datetime.date(2023, 1, 9), Decimal('527.5'), 'credit card'),
#  (460, 558, datetime.date(2022, 7, 7), Decimal('995.61'), 'credit card'),
#  (461, 441, datetime.date(2022, 7, 6), Decimal('1381.58'), 'phone'),
#  (462, 959, datetime.date(2022, 10, 8), Decimal('297.64'), 'credit card'),
#  (463, 507, datetime.date(2022, 8, 21), Decimal('661.64'), 'bank account'),
#  (464, 315, datetime.date(2022, 10, 6), Decimal('1333.75'), 'credit card'),
#  (465, 354, datetime.date(2022, 10, 27), Decimal('284.89'), 'credit card'),
#  (466, 677, datetime.date(2023, 2, 17), Decimal('2791.97'), 'phone'),
#  (467, 735, datetime.date(2022, 11, 28), Decimal('3313.94'), 'phone'),
#  (468, 898, datetime.date(2022, 10, 31), Decimal('1401.14'), 'phone'),
#  (469, 582, datetime.date(2022, 12, 21), Decimal('458.97'), 'mail'),
#  (470, 58, datetime.date(2022, 8, 4), Decimal('336.5'), 'mail'),
#  (471, 68, datetime.date(2023, 2, 25), Decimal('2727.11'), 'mail'),
#  (472, 272, datetime.date(2022, 12, 21), Decimal('1019.36'), 'credit card'),
#  (473, 371, datetime.date(2022, 8, 29), Decimal('1724.19'), 'mail'),
#  (474, 910, datetime.date(2022, 9, 8), Decimal('1521.33'), 'credit card'),
#  (475, 71, datetime.date(2022, 11, 14), Decimal('2910.31'), 'debit card'),
#  (476, 932, datetime.date(2022, 8, 29), Decimal('4498.36'), 'bank account'),
#  (477, 767, datetime.date(2022, 4, 16), Decimal('1375.19'), 'phone'),
#  (478, 705, datetime.date(2022, 8, 2), Decimal('1353.0'), 'credit card'),
#  (479, 287, datetime.date(2022, 11, 23), Decimal('386.28'), 'bank account'),
#  (480, 528, datetime.date(2022, 11, 28), Decimal('2034.69'), 'debit card'),
#  (481, 286, datetime.date(2022, 6, 7), Decimal('753.69'), 'bank account'),
#  (482, 741, datetime.date(2022, 12, 1), Decimal('344.56'), 'debit card'),
#  (483, 88, datetime.date(2022, 9, 20), Decimal('1478.81'), 'mail'),
#  (484, 340, datetime.date(2022, 5, 3), Decimal('2085.92'), 'phone'),
#  (485, 765, datetime.date(2022, 10, 1), Decimal('3040.22'), 'bank account'),
#  (486, 26, datetime.date(2023, 3, 15), Decimal('2820.69'), 'mail'),
#  (487, 772, datetime.date(2022, 12, 1), Decimal('3162.06'), 'credit card'),
#  (488, 641, datetime.date(2022, 11, 18), Decimal('320.39'), 'credit card'),
#  (489, 637, datetime.date(2023, 1, 29), Decimal('1512.22'), 'debit card'),
#  (490, 225, datetime.date(2022, 7, 23), Decimal('707.61'), 'mail'),
#  (491, 440, datetime.date(2022, 12, 30), Decimal('705.06'), 'debit card'),
#  (492, 322, datetime.date(2022, 6, 20), Decimal('1579.0'), 'debit card'),
#  (493, 14, datetime.date(2022, 7, 22), Decimal('3284.28'), 'mail'),
#  (494, 106, datetime.date(2022, 6, 13), Decimal('616.42'), 'bank account'),
#  (495, 194, datetime.date(2022, 9, 13), Decimal('1036.58'), 'mail'),
#  (496, 571, datetime.date(2023, 3, 8), Decimal('442.92'), 'credit card'),
#  (497, 395, datetime.date(2022, 11, 19), Decimal('297.28'), 'credit card'),
#  (498, 339, datetime.date(2022, 12, 13), Decimal('2523.64'), 'bank account'),
#  (499, 961, datetime.date(2022, 12, 10), Decimal('663.53'), 'phone'),
#  (500, 902, datetime.date(2022, 7, 11), Decimal('1079.72'), 'phone'),
#  (501, 751, datetime.date(2022, 4, 25), Decimal('1558.67'), 'mail'),
#  (502, 446, datetime.date(2022, 10, 30), Decimal('3751.33'), 'phone'),
#  (503, 402, datetime.date(2022, 10, 16), Decimal('530.78'), 'mail'),
#  (504, 882, datetime.date(2022, 10, 12), Decimal('300.86'), 'debit card'),
#  (505, 762, datetime.date(2023, 3, 21), Decimal('2180.0'), 'mail'),
#  (506, 691, datetime.date(2022, 12, 3), Decimal('354.47'), 'phone'),
#  (507, 17, datetime.date(2023, 2, 9), Decimal('2302.42'), 'debit card'),
#  (508, 967, datetime.date(2023, 1, 28), Decimal('1175.5'), 'mail'),
#  (509, 893, datetime.date(2022, 7, 22), Decimal('801.81'), 'credit card'),
#  (510, 211, datetime.date(2022, 11, 2), Decimal('738.92'), 'mail'),
#  (511, 943, datetime.date(2022, 6, 15), Decimal('457.72'), 'credit card'),
#  (512, 739, datetime.date(2022, 5, 16), Decimal('674.39'), 'debit card'),
#  (513, 363, datetime.date(2022, 9, 5), Decimal('2228.06'), 'bank account'),
#  (514, 336, datetime.date(2022, 6, 5), Decimal('1512.81'), 'mail'),
#  (515, 35, datetime.date(2023, 3, 13), Decimal('2414.19'), 'credit card'),
#  (516, 912, datetime.date(2022, 10, 17), Decimal('3779.61'), 'debit card'),
#  (517, 888, datetime.date(2023, 1, 30), Decimal('1211.08'), 'credit card'),
#  (518, 850, datetime.date(2022, 10, 19), Decimal('3202.22'), 'bank account'),
#  (519, 20, datetime.date(2022, 6, 8), Decimal('1064.81'), 'debit card'),
#  (520, 887, datetime.date(2022, 11, 27), Decimal('579.75'), 'mail'),
#  (521, 907, datetime.date(2022, 12, 27), Decimal('4009.22'), 'bank account'),
#  (522, 342, datetime.date(2022, 7, 30), Decimal('1541.39'), 'credit card'),
#  (523, 477, datetime.date(2023, 1, 8), Decimal('2884.89'), 'debit card'),
#  (524, 398, datetime.date(2022, 8, 9), Decimal('682.22'), 'debit card'),
#  (525, 953, datetime.date(2022, 10, 13), Decimal('1684.64'), 'phone'),
#  (526, 650, datetime.date(2022, 7, 23), Decimal('2281.25'), 'phone'),
#  (527, 31, datetime.date(2023, 1, 18), Decimal('1621.14'), 'phone'),
#  (528, 478, datetime.date(2022, 6, 7), Decimal('458.81'), 'debit card'),
#  (529, 27, datetime.date(2022, 5, 29), Decimal('2457.67'), 'bank account'),
#  (530, 314, datetime.date(2023, 4, 11), Decimal('1396.53'), 'phone'),
#  (531, 124, datetime.date(2022, 12, 22), Decimal('400.28'), 'bank account'),
#  (532, 224, datetime.date(2023, 2, 3), Decimal('863.53'), 'mail'),
#  (533, 937, datetime.date(2022, 7, 3), Decimal('1772.08'), 'bank account'),
#  (534, 451, datetime.date(2022, 8, 16), Decimal('549.19'), 'bank account'),
#  (535, 222, datetime.date(2022, 9, 30), Decimal('1524.75'), 'credit card'),
#  (536, 580, datetime.date(2023, 3, 13), Decimal('2675.81'), 'debit card'),
#  (537, 111, datetime.date(2022, 6, 25), Decimal('1024.89'), 'debit card'),
#  (538, 75, datetime.date(2022, 8, 24), Decimal('524.86'), 'debit card'),
#  (539, 693, datetime.date(2023, 4, 13), Decimal('908.44'), 'phone'),
#  (540, 669, datetime.date(2022, 5, 12), Decimal('1707.83'), 'credit card'),
#  (541, 413, datetime.date(2022, 8, 7), Decimal('3438.53'), 'credit card'),
#  (542, 979, datetime.date(2022, 7, 28), Decimal('1220.36'), 'bank account'),
#  (543, 86, datetime.date(2023, 3, 4), Decimal('1515.06'), 'credit card'),
#  (544, 2, datetime.date(2022, 10, 10), Decimal('3144.94'), 'mail'),
#  (545, 174, datetime.date(2023, 1, 19), Decimal('1261.14'), 'credit card'),
#  (546, 731, datetime.date(2023, 3, 5), Decimal('1297.72'), 'mail'),
#  (547, 473, datetime.date(2023, 1, 25), Decimal('488.11'), 'bank account'),
#  (548, 833, datetime.date(2023, 1, 22), Decimal('505.58'), 'debit card'),
#  (549, 617, datetime.date(2023, 3, 25), Decimal('941.33'), 'bank account'),
#  (550, 169, datetime.date(2022, 7, 2), Decimal('902.42'), 'credit card'),
#  (551, 709, datetime.date(2023, 1, 13), Decimal('4621.17'), 'debit card'),
#  (552, 34, datetime.date(2022, 11, 22), Decimal('1972.5'), 'mail'),
#  (553, 605, datetime.date(2022, 9, 8), Decimal('1310.47'), 'mail'),
#  (554, 793, datetime.date(2022, 6, 14), Decimal('523.81'), 'phone'),
#  (555, 936, datetime.date(2022, 11, 25), Decimal('705.14'), 'mail'),
#  (556, 889, datetime.date(2023, 4, 4), Decimal('4024.22'), 'debit card'),
#  (557, 13, datetime.date(2022, 9, 10), Decimal('360.53'), 'mail'),
#  (558, 436, datetime.date(2023, 3, 7), Decimal('1378.86'), 'bank account'),
#  (559, 911, datetime.date(2022, 7, 10), Decimal('340.0'), 'bank account'),
#  (560, 648, datetime.date(2022, 12, 7), Decimal('947.72'), 'mail'),
#  (561, 665, datetime.date(2022, 8, 1), Decimal('1935.78'), 'bank account'),
#  (562, 205, datetime.date(2023, 1, 2), Decimal('4148.97'), 'bank account'),
#  (563, 745, datetime.date(2023, 3, 11), Decimal('1769.25'), 'bank account'),
#  (564, 598, datetime.date(2022, 12, 10), Decimal('477.56'), 'credit card'),
#  (565, 711, datetime.date(2023, 2, 9), Decimal('474.31'), 'mail'),
#  (566, 781, datetime.date(2022, 10, 19), Decimal('1068.44'), 'credit card'),
#  (567, 387, datetime.date(2022, 6, 23), Decimal('735.0'), 'mail'),
#  (568, 501, datetime.date(2023, 3, 18), Decimal('952.47'), 'debit card'),
#  (569, 600, datetime.date(2022, 12, 29), Decimal('2499.5'), 'credit card'),
#  (570, 790, datetime.date(2022, 10, 11), Decimal('2063.53'), 'mail'),
#  (571, 470, datetime.date(2022, 12, 29), Decimal('741.67'), 'debit card'),
#  (572, 703, datetime.date(2022, 11, 8), Decimal('613.81'), 'mail'),
#  (573, 662, datetime.date(2023, 2, 14), Decimal('306.97'), 'debit card'),
#  (574, 517, datetime.date(2022, 6, 18), Decimal('1426.97'), 'bank account'),
#  (575, 40, datetime.date(2022, 7, 8), Decimal('431.56'), 'phone'),
#  (576, 780, datetime.date(2022, 5, 11), Decimal('1204.94'), 'credit card'),
#  (577, 865, datetime.date(2022, 9, 10), Decimal('577.83'), 'debit card'),
#  (578, 330, datetime.date(2022, 8, 23), Decimal('799.83'), 'debit card'),
#  (579, 784, datetime.date(2022, 6, 4), Decimal('1336.36'), 'phone'),
#  (580, 317, datetime.date(2022, 12, 10), Decimal('2888.56'), 'mail'),
#  (581, 861, datetime.date(2023, 1, 17), Decimal('2844.64'), 'bank account'),
#  (582, 698, datetime.date(2023, 1, 23), Decimal('1692.56'), 'phone'),
#  (583, 740, datetime.date(2023, 3, 9), Decimal('3345.61'), 'mail'),
#  (584, 829, datetime.date(2022, 7, 4), Decimal('3057.56'), 'bank account'),
#  (585, 494, datetime.date(2023, 2, 4), Decimal('3716.67'), 'credit card'),
#  (586, 984, datetime.date(2022, 7, 23), Decimal('2723.31'), 'phone'),
#  (587, 720, datetime.date(2022, 12, 18), Decimal('1936.86'), 'credit card'),
#  (588, 849, datetime.date(2022, 6, 15), Decimal('2259.31'), 'bank account'),
#  (589, 53, datetime.date(2022, 6, 9), Decimal('1500.67'), 'debit card'),
#  (590, 393, datetime.date(2022, 5, 13), Decimal('462.19'), 'phone'),
#  (591, 964, datetime.date(2022, 10, 12), Decimal('1606.0'), 'bank account'),
#  (592, 690, datetime.date(2023, 2, 26), Decimal('3976.42'), 'mail'),
#  (593, 247, datetime.date(2022, 12, 17), Decimal('600.56'), 'debit card'),
#  (594, 777, datetime.date(2022, 5, 19), Decimal('431.25'), 'phone'),
#  (595, 667, datetime.date(2022, 6, 26), Decimal('3350.14'), 'mail'),
#  (596, 5, datetime.date(2022, 5, 24), Decimal('1146.56'), 'debit card'),
#  (597, 81, datetime.date(2022, 5, 23), Decimal('878.14'), 'debit card'),
#  (598, 597, datetime.date(2022, 10, 10), Decimal('566.53'), 'credit card'),
#  (599, 179, datetime.date(2023, 1, 21), Decimal('1923.75'), 'mail'),
#  (600, 858, datetime.date(2022, 9, 2), Decimal('1541.69'), 'debit card'),
#  (601, 576, datetime.date(2022, 10, 10), Decimal('1878.22'), 'debit card'),
#  (602, 196, datetime.date(2022, 10, 20), Decimal('282.64'), 'mail'),
#  (603, 55, datetime.date(2023, 1, 28), Decimal('3489.72'), 'phone'),
#  (604, 716, datetime.date(2022, 4, 19), Decimal('1698.44'), 'bank account'),
#  (605, 268, datetime.date(2023, 1, 5), Decimal('1185.22'), 'bank account'),
#  (606, 615, datetime.date(2022, 8, 15), Decimal('952.58'), 'bank account'),
#  (607, 434, datetime.date(2023, 4, 4), Decimal('573.53'), 'credit card'),
#  (608, 746, datetime.date(2023, 2, 25), Decimal('2210.78'), 'mail'),
#  (609, 256, datetime.date(2023, 4, 13), Decimal('589.94'), 'phone'),
#  (610, 255, datetime.date(2022, 12, 30), Decimal('1487.06'), 'mail'),
#  (611, 69, datetime.date(2022, 9, 11), Decimal('593.64'), 'mail'),
#  (612, 896, datetime.date(2022, 7, 4), Decimal('1141.67'), 'credit card'),
#  (613, 950, datetime.date(2023, 2, 27), Decimal('958.53'), 'debit card'),
#  (614, 99, datetime.date(2022, 6, 17), Decimal('2555.5'), 'phone'),
#  (615, 10, datetime.date(2022, 8, 17), Decimal('1870.19'), 'mail'),
#  (616, 91, datetime.date(2022, 7, 4), Decimal('840.92'), 'mail'),
#  (617, 702, datetime.date(2022, 10, 19), Decimal('3499.56'), 'debit card'),
#  (618, 526, datetime.date(2023, 3, 20), Decimal('3644.17'), 'debit card'),
#  (619, 248, datetime.date(2022, 6, 6), Decimal('2602.94'), 'phone'),
#  (620, 812, datetime.date(2022, 10, 29), Decimal('1295.81'), 'debit card'),
#  (621, 359, datetime.date(2022, 8, 5), Decimal('327.28'), 'credit card'),
#  (622, 827, datetime.date(2023, 2, 26), Decimal('2716.67'), 'bank account'),
#  (623, 603, datetime.date(2022, 11, 16), Decimal('644.28'), 'mail'),
#  (624, 166, datetime.date(2023, 2, 3), Decimal('279.94'), 'debit card'),
#  (625, 763, datetime.date(2022, 6, 25), Decimal('855.03'), 'bank account'),
#  (626, 939, datetime.date(2022, 5, 11), Decimal('1789.33'), 'phone'),
#  (627, 404, datetime.date(2022, 6, 25), Decimal('1976.83'), 'mail'),
#  (628, 439, datetime.date(2022, 10, 13), Decimal('737.25'), 'bank account'),
#  (629, 291, datetime.date(2023, 2, 12), Decimal('3214.0'), 'credit card'),
#  (630, 680, datetime.date(2022, 9, 29), Decimal('2743.28'), 'phone'),
#  (631, 258, datetime.date(2023, 3, 28), Decimal('2722.14'), 'debit card'),
#  (632, 155, datetime.date(2022, 8, 22), Decimal('753.67'), 'phone'),
#  (633, 555, datetime.date(2022, 10, 14), Decimal('746.19'), 'credit card'),
#  (634, 514, datetime.date(2023, 3, 20), Decimal('2965.5'), 'debit card'),
#  (635, 575, datetime.date(2022, 4, 24), Decimal('1267.33'), 'credit card'),
#  (636, 356, datetime.date(2022, 8, 20), Decimal('461.28'), 'mail'),
#  (637, 993, datetime.date(2022, 5, 23), Decimal('283.39'), 'credit card'),
#  (638, 139, datetime.date(2022, 8, 25), Decimal('1344.42'), 'mail'),
#  (639, 975, datetime.date(2022, 8, 12), Decimal('1288.61'), 'mail'),
#  (640, 417, datetime.date(2022, 7, 11), Decimal('5037.22'), 'bank account'),
#  (641, 167, datetime.date(2022, 10, 10), Decimal('659.61'), 'mail'),
#  (642, 389, datetime.date(2022, 10, 19), Decimal('1559.86'), 'mail'),
#  (643, 966, datetime.date(2022, 5, 25), Decimal('2024.58'), 'credit card'),
#  (644, 530, datetime.date(2022, 9, 30), Decimal('746.42'), 'mail'),
#  (645, 227, datetime.date(2022, 5, 2), Decimal('3312.92'), 'credit card'),
#  (646, 74, datetime.date(2023, 2, 7), Decimal('2142.42'), 'credit card'),
#  (647, 997, datetime.date(2022, 7, 30), Decimal('1258.0'), 'bank account'),
#  (648, 154, datetime.date(2022, 9, 14), Decimal('3395.06'), 'mail'),
#  (649, 30, datetime.date(2022, 8, 30), Decimal('2030.0'), 'bank account'),
#  (650, 684, datetime.date(2023, 4, 15), Decimal('2183.22'), 'bank account'),
#  (651, 919, datetime.date(2022, 6, 20), Decimal('1810.78'), 'phone'),
#  (652, 484, datetime.date(2022, 10, 27), Decimal('465.0'), 'mail'),
#  (653, 701, datetime.date(2023, 2, 5), Decimal('1735.75'), 'bank account'),
#  (654, 595, datetime.date(2022, 12, 14), Decimal('2084.67'), 'debit card'),
#  (655, 809, datetime.date(2022, 6, 6), Decimal('309.42'), 'debit card'),
#  (656, 98, datetime.date(2022, 8, 27), Decimal('537.0'), 'phone'),
#  (657, 283, datetime.date(2022, 6, 9), Decimal('1219.28'), 'bank account'),
#  (658, 824, datetime.date(2023, 3, 15), Decimal('1477.17'), 'mail'),
#  (659, 260, datetime.date(2022, 8, 11), Decimal('1219.83'), 'bank account'),
#  (660, 77, datetime.date(2022, 5, 18), Decimal('737.92'), 'debit card'),
#  (661, 992, datetime.date(2022, 5, 26), Decimal('863.75'), 'mail'),
#  (662, 300, datetime.date(2023, 3, 6), Decimal('354.89'), 'mail'),
#  (663, 585, datetime.date(2022, 12, 20), Decimal('566.03'), 'bank account'),
# ...
#  (780, 573, datetime.date(2022, 10, 28), Decimal('494.58'), 'debit card'),
#  (781, 309, datetime.date(2023, 3, 5), Decimal('2562.78'), 'phone'),
#  (782, 1, datetime.date(2022, 12, 28), Decimal('1156.44'), 'credit card'),
#  (783, 756, datetime.date(2022, 7, 8), Decimal('868.53'), 'debit card'),
#  (784, 244, datetime.date(2023, 1, 4), Decimal('1557.36'), 'phone'),
#  (785, 909, datetime.date(2022, 7, 10), Decimal('492.33'), 'bank account'),
#  (786, 429, datetime.date(2022, 8, 19), Decimal('791.94'), 'bank account'),
#  (787, 877, datetime.date(2023, 2, 21), Decimal('1061.19'), 'bank account'),
#  (788, 57, datetime.date(2022, 6, 6), Decimal('4125.03'), 'mail'),
#  (789, 548, datetime.date(2023, 4, 9), Decimal('697.11'), 'phone'),
#  (790, 536, datetime.date(2022, 5, 25), Decimal('290.33'), 'debit card'),
#  (791, 663, datetime.date(2023, 3, 7), Decimal('1255.42'), 'credit card'),
#  (792, 385, datetime.date(2022, 9, 21), Decimal('3984.33'), 'mail'),
#  (793, 785, datetime.date(2023, 2, 7), Decimal('2126.5'), 'phone'),
#  (794, 217, datetime.date(2022, 9, 23), Decimal('1074.08'), 'phone'),
#  (795, 12, datetime.date(2022, 8, 10), Decimal('2936.78'), 'debit card'),
#  (796, 854, datetime.date(2022, 5, 1), Decimal('563.33'), 'phone'),
#  (797, 983, datetime.date(2023, 1, 16), Decimal('1057.83'), 'mail'),
#  (798, 578, datetime.date(2022, 5, 31), Decimal('1425.31'), 'credit card'),
#  (799, 826, datetime.date(2022, 7, 16), Decimal('338.33'), 'mail'),
#  (800, 301, datetime.date(2022, 12, 16), Decimal('4103.28'), 'phone'),
#  (801, 498, datetime.date(2023, 1, 5), Decimal('3607.17'), 'mail'),
#  (802, 228, datetime.date(2022, 5, 6), Decimal('662.0'), 'bank account'),
#  (803, 276, datetime.date(2022, 7, 14), Decimal('412.92'), 'bank account'),
#  (804, 90, datetime.date(2022, 4, 26), Decimal('335.56'), 'phone'),
#  (805, 449, datetime.date(2023, 3, 12), Decimal('423.5'), 'mail'),
#  (806, 250, datetime.date(2023, 3, 4), Decimal('2591.08'), 'debit card'),
#  (807, 788, datetime.date(2022, 8, 8), Decimal('676.58'), 'phone'),
#  (808, 796, datetime.date(2022, 8, 3), Decimal('312.39'), 'debit card'),
#  (809, 632, datetime.date(2022, 9, 6), Decimal('2047.31'), 'phone'),
#  (810, 927, datetime.date(2022, 7, 11), Decimal('3114.89'), 'mail'),
#  (811, 116, datetime.date(2022, 6, 8), Decimal('664.94'), 'credit card'),
#  (812, 779, datetime.date(2022, 10, 22), Decimal('2890.67'), 'phone'),
#  (813, 931, datetime.date(2022, 7, 4), Decimal('1749.53'), 'bank account'),
#  (814, 326, datetime.date(2022, 8, 17), Decimal('826.56'), 'credit card'),
#  (815, 475, datetime.date(2022, 10, 27), Decimal('291.03'), 'debit card'),
#  (816, 612, datetime.date(2022, 10, 3), Decimal('1737.17'), 'debit card'),
#  (817, 239, datetime.date(2023, 3, 27), Decimal('1017.81'), 'credit card'),
#  (818, 113, datetime.date(2023, 1, 22), Decimal('594.78'), 'mail'),
#  (819, 883, datetime.date(2022, 12, 12), Decimal('2733.42'), 'bank account'),
#  (820, 433, datetime.date(2022, 11, 4), Decimal('949.33'), 'debit card'),
#  (821, 642, datetime.date(2022, 10, 21), Decimal('3117.14'), 'mail'),
#  (822, 232, datetime.date(2023, 4, 10), Decimal('1718.19'), 'debit card'),
#  (823, 249, datetime.date(2022, 5, 2), Decimal('4347.75'), 'mail'),
#  (824, 414, datetime.date(2022, 5, 18), Decimal('4932.0'), 'mail'),
#  (825, 358, datetime.date(2022, 5, 31), Decimal('1208.06'), 'debit card'),
#  (826, 537, datetime.date(2022, 4, 26), Decimal('586.17'), 'mail'),
#  (827, 890, datetime.date(2022, 12, 19), Decimal('417.81'), 'mail'),
#  (828, 93, datetime.date(2022, 11, 4), Decimal('384.36'), 'credit card'),
#  (829, 445, datetime.date(2022, 11, 16), Decimal('763.5'), 'mail'),
#  (830, 119, datetime.date(2022, 11, 3), Decimal('1854.75'), 'phone'),
#  (831, 588, datetime.date(2022, 9, 2), Decimal('3607.06'), 'credit card'),
#  (832, 629, datetime.date(2023, 2, 28), Decimal('3127.72'), 'bank account'),
#  (833, 921, datetime.date(2022, 5, 29), Decimal('469.69'), 'debit card'),
#  (834, 171, datetime.date(2023, 3, 12), Decimal('501.0'), 'mail'),
#  (835, 110, datetime.date(2022, 8, 15), Decimal('445.78'), 'phone'),
#  (836, 223, datetime.date(2022, 12, 3), Decimal('573.89'), 'mail'),
#  (837, 401, datetime.date(2022, 10, 13), Decimal('451.58'), 'phone'),
#  (838, 183, datetime.date(2023, 2, 9), Decimal('995.58'), 'phone'),
#  (839, 800, datetime.date(2022, 5, 10), Decimal('1488.14'), 'credit card'),
#  (840, 949, datetime.date(2022, 11, 27), Decimal('3077.06'), 'credit card'),
#  (841, 135, datetime.date(2022, 6, 20), Decimal('3439.42'), 'credit card'),
#  (842, 737, datetime.date(2022, 12, 26), Decimal('3115.22'), 'mail'),
#  (843, 656, datetime.date(2022, 10, 17), Decimal('1032.78'), 'mail'),
#  (844, 245, datetime.date(2022, 9, 24), Decimal('2254.33'), 'phone'),
#  (845, 78, datetime.date(2022, 4, 26), Decimal('1748.89'), 'debit card'),
#  (846, 533, datetime.date(2022, 7, 25), Decimal('1117.11'), 'mail'),
#  (847, 719, datetime.date(2022, 12, 11), Decimal('3801.64'), 'mail'),
#  (848, 348, datetime.date(2022, 11, 3), Decimal('3989.31'), 'mail'),
#  (849, 390, datetime.date(2022, 8, 20), Decimal('1434.19'), 'mail'),
#  (850, 101, datetime.date(2022, 6, 21), Decimal('1963.47'), 'debit card'),
#  (851, 673, datetime.date(2023, 1, 2), Decimal('343.69'), 'credit card'),
#  (852, 163, datetime.date(2022, 6, 26), Decimal('1091.81'), 'phone'),
#  (853, 312, datetime.date(2022, 7, 22), Decimal('426.22'), 'phone'),
#  (854, 409, datetime.date(2023, 2, 22), Decimal('3292.53'), 'debit card'),
#  (855, 391, datetime.date(2023, 2, 16), Decimal('791.89'), 'debit card'),
#  (856, 143, datetime.date(2023, 3, 26), Decimal('1991.5'), 'bank account'),
#  (857, 132, datetime.date(2023, 3, 9), Decimal('1165.61'), 'credit card'),
#  (858, 830, datetime.date(2022, 12, 30), Decimal('406.36'), 'mail'),
#  (859, 298, datetime.date(2022, 7, 22), Decimal('1413.11'), 'bank account'),
#  (860, 502, datetime.date(2023, 1, 2), Decimal('2454.39'), 'debit card'),
#  (861, 307, datetime.date(2022, 12, 5), Decimal('3712.25'), 'debit card'),
#  (862, 923, datetime.date(2022, 7, 16), Decimal('2269.64'), 'debit card'),
#  (863, 840, datetime.date(2023, 2, 3), Decimal('512.5'), 'mail'),
#  (864, 400, datetime.date(2022, 6, 26), Decimal('377.75'), 'mail'),
#  (865, 655, datetime.date(2022, 12, 13), Decimal('479.94'), 'debit card'),
#  (866, 269, datetime.date(2022, 12, 22), Decimal('696.47'), 'bank account'),
#  (867, 509, datetime.date(2023, 2, 4), Decimal('2972.44'), 'phone'),
#  (868, 427, datetime.date(2023, 3, 11), Decimal('291.67'), 'bank account'),
#  (869, 822, datetime.date(2023, 2, 20), Decimal('2147.36'), 'debit card'),
#  (870, 900, datetime.date(2022, 6, 16), Decimal('1777.25'), 'credit card'),
#  (871, 104, datetime.date(2022, 8, 26), Decimal('2835.53'), 'phone'),
#  (872, 747, datetime.date(2023, 1, 30), Decimal('4247.36'), 'phone'),
#  (873, 305, datetime.date(2022, 7, 18), Decimal('342.86'), 'mail'),
#  (874, 497, datetime.date(2022, 9, 8), Decimal('733.92'), 'mail'),
#  (875, 636, datetime.date(2022, 5, 6), Decimal('2084.47'), 'mail'),
#  (876, 700, datetime.date(2022, 12, 25), Decimal('731.75'), 'debit card'),
#  (877, 651, datetime.date(2022, 8, 5), Decimal('1265.56'), 'bank account'),
#  (878, 998, datetime.date(2023, 3, 5), Decimal('967.06'), 'bank account'),
#  (879, 977, datetime.date(2022, 11, 6), Decimal('913.97'), 'phone'),
#  (880, 676, datetime.date(2023, 1, 26), Decimal('315.56'), 'mail'),
#  (881, 707, datetime.date(2023, 1, 16), Decimal('1484.25'), 'bank account'),
#  (882, 523, datetime.date(2022, 6, 24), Decimal('2204.61'), 'phone'),
#  (883, 140, datetime.date(2022, 10, 27), Decimal('301.78'), 'bank account'),
#  (884, 396, datetime.date(2023, 4, 1), Decimal('2920.25'), 'bank account'),
#  (885, 773, datetime.date(2022, 7, 7), Decimal('421.31'), 'mail'),
#  (886, 543, datetime.date(2022, 8, 31), Decimal('660.11'), 'mail'),
#  (887, 125, datetime.date(2022, 9, 17), Decimal('1530.06'), 'mail'),
#  (888, 343, datetime.date(2022, 12, 21), Decimal('3484.78'), 'credit card'),
#  (889, 274, datetime.date(2023, 4, 16), Decimal('2881.14'), 'mail'),
#  (890, 491, datetime.date(2023, 4, 7), Decimal('1104.31'), 'debit card'),
#  (891, 201, datetime.date(2023, 4, 9), Decimal('662.56'), 'bank account'),
#  (892, 190, datetime.date(2023, 2, 25), Decimal('1057.56'), 'debit card'),
#  (893, 36, datetime.date(2023, 1, 11), Decimal('788.53'), 'mail'),
#  (894, 836, datetime.date(2022, 7, 18), Decimal('3489.61'), 'debit card'),
#  (895, 938, datetime.date(2022, 12, 30), Decimal('565.06'), 'bank account'),
#  (896, 749, datetime.date(2022, 10, 2), Decimal('324.94'), 'mail'),
#  (897, 311, datetime.date(2023, 2, 24), Decimal('444.5'), 'bank account'),
#  (898, 65, datetime.date(2023, 3, 25), Decimal('555.44'), 'mail'),
#  (899, 103, datetime.date(2022, 10, 31), Decimal('278.67'), 'phone'),
#  (900, 945, datetime.date(2022, 8, 23), Decimal('4622.92'), 'debit card'),
#  (901, 572, datetime.date(2022, 10, 19), Decimal('1161.11'), 'bank account'),
#  (902, 351, datetime.date(2022, 10, 28), Decimal('960.17'), 'credit card'),
#  (903, 495, datetime.date(2023, 1, 14), Decimal('1808.14'), 'bank account'),
#  (904, 738, datetime.date(2022, 12, 9), Decimal('337.22'), 'credit card'),
#  (905, 714, datetime.date(2022, 7, 11), Decimal('1760.67'), 'phone'),
#  (906, 43, datetime.date(2022, 10, 26), Decimal('3196.97'), 'phone'),
#  (907, 443, datetime.date(2022, 8, 27), Decimal('299.81'), 'debit card'),
#  (908, 54, datetime.date(2023, 4, 1), Decimal('2965.42'), 'credit card'),
#  (909, 566, datetime.date(2023, 3, 5), Decimal('3594.67'), 'mail'),
#  (910, 506, datetime.date(2023, 4, 13), Decimal('1185.5'), 'debit card'),
#  (911, 469, datetime.date(2022, 12, 2), Decimal('2403.78'), 'phone'),
#  (912, 1000, datetime.date(2023, 2, 22), Decimal('492.19'), 'debit card'),
#  (913, 161, datetime.date(2022, 6, 16), Decimal('4947.78'), 'bank account'),
#  (914, 206, datetime.date(2022, 8, 19), Decimal('304.17'), 'phone'),
#  (915, 859, datetime.date(2022, 11, 22), Decimal('731.78'), 'mail'),
#  (916, 375, datetime.date(2022, 6, 27), Decimal('2575.58'), 'mail'),
#  (917, 92, datetime.date(2023, 2, 2), Decimal('1396.31'), 'debit card'),
#  (918, 219, datetime.date(2023, 1, 25), Decimal('333.22'), 'mail'),
#  (919, 266, datetime.date(2022, 12, 12), Decimal('278.47'), 'phone'),
#  (920, 541, datetime.date(2022, 4, 26), Decimal('1003.69'), 'debit card'),
#  (921, 742, datetime.date(2022, 6, 23), Decimal('299.83'), 'bank account'),
#  (922, 448, datetime.date(2022, 12, 17), Decimal('1070.14'), 'phone'),
#  (923, 209, datetime.date(2022, 4, 25), Decimal('659.11'), 'mail'),
#  (924, 488, datetime.date(2023, 3, 9), Decimal('918.81'), 'mail'),
#  (925, 117, datetime.date(2023, 1, 24), Decimal('2390.25'), 'mail'),
#  (926, 844, datetime.date(2022, 11, 25), Decimal('3511.33'), 'phone'),
#  (927, 534, datetime.date(2022, 6, 21), Decimal('4436.33'), 'debit card'),
#  (928, 45, datetime.date(2022, 11, 7), Decimal('1014.19'), 'bank account'),
#  (929, 744, datetime.date(2023, 1, 7), Decimal('537.69'), 'mail'),
#  (930, 197, datetime.date(2022, 10, 7), Decimal('1073.94'), 'credit card'),
#  (931, 438, datetime.date(2022, 10, 15), Decimal('574.22'), 'credit card'),
#  (932, 430, datetime.date(2022, 8, 4), Decimal('1542.44'), 'bank account'),
#  (933, 364, datetime.date(2022, 5, 10), Decimal('2071.81'), 'mail'),
#  (934, 856, datetime.date(2022, 7, 5), Decimal('953.64'), 'phone'),
#  (935, 870, datetime.date(2022, 5, 2), Decimal('1379.22'), 'debit card'),
#  (936, 278, datetime.date(2022, 8, 20), Decimal('608.31'), 'credit card'),
#  (937, 202, datetime.date(2023, 4, 16), Decimal('2123.81'), 'mail'),
#  (938, 146, datetime.date(2022, 7, 2), Decimal('1790.25'), 'phone'),
#  (939, 405, datetime.date(2022, 6, 7), Decimal('1237.86'), 'phone'),
#  (940, 914, datetime.date(2022, 12, 5), Decimal('431.39'), 'credit card'),
#  (941, 897, datetime.date(2022, 6, 4), Decimal('2735.36'), 'debit card'),
#  (942, 37, datetime.date(2022, 9, 5), Decimal('3247.92'), 'phone'),
#  (943, 758, datetime.date(2023, 2, 28), Decimal('1061.08'), 'mail'),
#  (944, 95, datetime.date(2022, 8, 5), Decimal('2107.47'), 'debit card'),
#  (945, 891, datetime.date(2022, 11, 29), Decimal('1242.47'), 'debit card'),
#  (946, 590, datetime.date(2022, 11, 10), Decimal('2356.69'), 'phone'),
#  (947, 288, datetime.date(2022, 7, 20), Decimal('2402.03'), 'phone'),
#  (948, 551, datetime.date(2023, 3, 31), Decimal('2581.5'), 'debit card'),
#  (949, 955, datetime.date(2023, 4, 13), Decimal('439.69'), 'bank account'),
#  (950, 377, datetime.date(2022, 12, 25), Decimal('568.06'), 'phone'),
#  (951, 318, datetime.date(2022, 7, 4), Decimal('3457.19'), 'credit card'),
#  (952, 535, datetime.date(2022, 12, 10), Decimal('1347.64'), 'bank account'),
#  (953, 960, datetime.date(2022, 8, 24), Decimal('3743.94'), 'mail'),
#  (954, 41, datetime.date(2023, 3, 13), Decimal('445.94'), 'credit card'),
#  (955, 679, datetime.date(2022, 10, 27), Decimal('1183.92'), 'phone'),
#  (956, 521, datetime.date(2023, 1, 29), Decimal('2740.94'), 'credit card'),
#  (957, 905, datetime.date(2023, 3, 14), Decimal('420.97'), 'phone'),
#  (958, 425, datetime.date(2022, 6, 27), Decimal('396.14'), 'mail'),
#  (959, 444, datetime.date(2023, 3, 23), Decimal('2117.08'), 'bank account'),
#  (960, 233, datetime.date(2022, 7, 29), Decimal('292.81'), 'credit card'),
#  (961, 587, datetime.date(2022, 8, 15), Decimal('776.44'), 'phone'),
#  (962, 15, datetime.date(2023, 1, 11), Decimal('797.25'), 'mail'),
#  (963, 978, datetime.date(2022, 11, 23), Decimal('919.58'), 'debit card'),
#  (964, 191, datetime.date(2022, 10, 6), Decimal('1698.83'), 'credit card'),
#  (965, 353, datetime.date(2022, 9, 15), Decimal('2225.92'), 'mail'),
#  (966, 82, datetime.date(2022, 12, 6), Decimal('1344.83'), 'mail'),
#  (967, 925, datetime.date(2022, 12, 31), Decimal('2046.36'), 'credit card'),
#  (968, 869, datetime.date(2022, 11, 16), Decimal('524.92'), 'debit card'),
#  (969, 522, datetime.date(2022, 7, 18), Decimal('2754.72'), 'debit card'),
#  (970, 279, datetime.date(2022, 8, 11), Decimal('866.83'), 'debit card'),
#  (971, 22, datetime.date(2023, 4, 5), Decimal('525.86'), 'mail'),
#  (972, 688, datetime.date(2022, 12, 22), Decimal('1666.39'), 'bank account'),
#  (973, 280, datetime.date(2022, 8, 22), Decimal('764.53'), 'phone'),
#  (974, 847, datetime.date(2022, 12, 25), Decimal('1092.47'), 'debit card'),
#  (975, 24, datetime.date(2022, 11, 2), Decimal('2812.14'), 'mail'),
#  (976, 212, datetime.date(2022, 5, 23), Decimal('3063.28'), 'phone'),
#  (977, 944, datetime.date(2022, 8, 28), Decimal('2539.89'), 'bank account'),
#  (978, 406, datetime.date(2022, 4, 18), Decimal('974.94'), 'mail'),
#  (979, 608, datetime.date(2022, 12, 4), Decimal('2137.31'), 'phone'),
#  (980, 787, datetime.date(2023, 1, 6), Decimal('2481.17'), 'mail'),
#  (981, 729, datetime.date(2023, 3, 23), Decimal('1019.47'), 'phone'),
#  (982, 471, datetime.date(2022, 12, 15), Decimal('2994.94'), 'mail'),
#  (983, 750, datetime.date(2022, 7, 12), Decimal('335.61'), 'mail'),
#  (984, 879, datetime.date(2023, 3, 7), Decimal('1027.61'), 'phone'),
#  (985, 320, datetime.date(2023, 2, 23), Decimal('3248.72'), 'bank account'),
#  (986, 686, datetime.date(2022, 10, 31), Decimal('4983.89'), 'bank account'),
#  (987, 180, datetime.date(2022, 5, 2), Decimal('2388.0'), 'mail'),
#  (988, 308, datetime.date(2023, 4, 12), Decimal('2117.14'), 'mail'),
#  (989, 422, datetime.date(2022, 4, 22), Decimal('720.86'), 'phone'),
#  (990, 79, datetime.date(2023, 3, 30), Decimal('965.03'), 'mail'),
#  (991, 324, datetime.date(2023, 3, 18), Decimal('1067.28'), 'credit card'),
#  (992, 437, datetime.date(2023, 1, 2), Decimal('291.67'), 'mail'),
#  (993, 880, datetime.date(2022, 6, 4), Decimal('615.69'), 'debit card'),
#  (994, 696, datetime.date(2023, 1, 19), Decimal('1386.58'), 'debit card'),
#  (995, 493, datetime.date(2022, 5, 23), Decimal('1434.03'), 'bank account'),
#  (996, 721, datetime.date(2022, 4, 23), Decimal('2598.03'), 'credit card'),
#  (997, 85, datetime.date(2022, 7, 3), Decimal('427.47'), 'credit card'),
#  (998, 335, datetime.date(2022, 7, 15), Decimal('769.94'), 'credit card'),
#  (999, 210, datetime.date(2022, 6, 1), Decimal('1209.36'), 'debit card'),
#  (1000, 799, datetime.date(2022, 12, 17), Decimal('3397.08'), 'credit card'),
#  ...]

# %% [markdown]
# ## Task 3
# <p>Starting on January 1st, 2022, all US clients started to use an online signing system.</p>
# <p>The analytics team wants to analyze the loan portfolio for the US clients via the new online signing system.</p>
# <p><img src="https://assets.datacamp.com/production/project_1748/img/lending_schema.png" alt="database schema"></p>
# <p>Write a query that returns the data for the analytics team. Your output should include <code>client_id</code>,<code>contract_date</code>, <code>principal_amount</code> and <code>loan_type</code> columns.</p>

# %%
# %%sql
# postgresql:///lending
#
# -- Keep the two lines above
# -- Start your answers here..
#
# SELECT
#     client.client_id,
#     contract.contract_date,
#     loan.principal_amount,
#     loan.loan_type
# FROM
#     client
# JOIN
#     loan ON client.client_id = loan.client_id
# JOIN
#     contract ON loan.contract_id = contract.contract_id
# WHERE
#     client.country = 'USA'
#     AND contract.contract_date >= '2022-01-01';
# Out:
# 94 rows affected.
# [(267, datetime.date(2022, 3, 8), Decimal('179230'), 'personal'),
#  (50, datetime.date(2022, 1, 13), Decimal('143729'), 'mortgage'),
#  (280, datetime.date(2022, 1, 2), Decimal('171122'), 'car'),
#  (79, datetime.date(2022, 1, 24), Decimal('43784'), 'mortgage'),
#  (245, datetime.date(2022, 1, 3), Decimal('95003'), 'mortgage'),
#  (181, datetime.date(2022, 2, 16), Decimal('45866'), 'mortgage'),
#  (194, datetime.date(2022, 1, 3), Decimal('174800'), 'car'),
#  (251, datetime.date(2022, 4, 14), Decimal('93214'), 'personal'),
#  (128, datetime.date(2022, 3, 27), Decimal('44186'), 'personal'),
#  (211, datetime.date(2022, 3, 18), Decimal('107766'), 'car'),
#  (86, datetime.date(2022, 3, 14), Decimal('189723'), 'car'),
#  (267, datetime.date(2022, 3, 7), Decimal('89311'), 'personal'),
#  (50, datetime.date(2022, 3, 24), Decimal('150547'), 'personal'),
#  (42, datetime.date(2022, 1, 10), Decimal('44279'), 'mortgage'),
#  (252, datetime.date(2022, 3, 24), Decimal('161071'), 'car'),
#  (225, datetime.date(2022, 3, 27), Decimal('96093'), 'personal'),
#  (105, datetime.date(2022, 3, 7), Decimal('54247'), 'mortgage'),
#  (57, datetime.date(2022, 4, 3), Decimal('72734'), 'mortgage'),
#  (232, datetime.date(2022, 3, 10), Decimal('23091'), 'car'),
#  (172, datetime.date(2022, 1, 31), Decimal('182274'), 'car'),
#  (24, datetime.date(2022, 2, 17), Decimal('76143'), 'car'),
#  (88, datetime.date(2022, 2, 17), Decimal('149806'), 'car'),
#  (282, datetime.date(2022, 2, 11), Decimal('196673'), 'personal'),
#  (105, datetime.date(2022, 2, 6), Decimal('194934'), 'personal'),
#  (70, datetime.date(2022, 3, 24), Decimal('179598'), 'mortgage'),
#  (109, datetime.date(2022, 1, 21), Decimal('198782'), 'personal'),
#  (46, datetime.date(2022, 4, 7), Decimal('133511'), 'mortgage'),
#  (156, datetime.date(2022, 3, 13), Decimal('145258'), 'car'),
#  (210, datetime.date(2022, 1, 1), Decimal('142956'), 'car'),
#  (14, datetime.date(2022, 1, 27), Decimal('186635'), 'personal'),
#  (171, datetime.date(2022, 4, 3), Decimal('53064'), 'personal'),
#  (157, datetime.date(2022, 1, 3), Decimal('137595'), 'mortgage'),
#  (54, datetime.date(2022, 2, 10), Decimal('62475'), 'personal'),
#  (208, datetime.date(2022, 1, 12), Decimal('153975'), 'car'),
#  (136, datetime.date(2022, 1, 8), Decimal('38320'), 'car'),
#  (280, datetime.date(2022, 3, 20), Decimal('40417'), 'personal'),
#  (42, datetime.date(2022, 1, 31), Decimal('134307'), 'mortgage'),
#  (56, datetime.date(2022, 2, 23), Decimal('129726'), 'mortgage'),
#  (225, datetime.date(2022, 1, 29), Decimal('78817'), 'mortgage'),
#  (160, datetime.date(2022, 4, 1), Decimal('196207'), 'mortgage'),
#  (89, datetime.date(2022, 3, 14), Decimal('39459'), 'personal'),
#  (38, datetime.date(2022, 4, 2), Decimal('61322'), 'mortgage'),
#  (182, datetime.date(2022, 4, 12), Decimal('116800'), 'car'),
#  (147, datetime.date(2022, 2, 18), Decimal('105363'), 'car'),
#  (39, datetime.date(2022, 4, 14), Decimal('122335'), 'car'),
#  (154, datetime.date(2022, 3, 24), Decimal('148392'), 'car'),
#  (8, datetime.date(2022, 1, 8), Decimal('13484'), 'personal'),
#  (73, datetime.date(2022, 4, 14), Decimal('135750'), 'personal'),
#  (282, datetime.date(2022, 2, 7), Decimal('17008'), 'personal'),
#  (267, datetime.date(2022, 1, 24), Decimal('128020'), 'mortgage'),
#  (122, datetime.date(2022, 2, 17), Decimal('108920'), 'personal'),
#  (12, datetime.date(2022, 2, 4), Decimal('69421'), 'personal'),
#  (1, datetime.date(2022, 1, 3), Decimal('95309'), 'mortgage'),
#  (54, datetime.date(2022, 2, 16), Decimal('197907'), 'personal'),
#  (234, datetime.date(2022, 1, 12), Decimal('17567'), 'car'),
#  (89, datetime.date(2022, 2, 21), Decimal('139309'), 'car'),
#  (270, datetime.date(2022, 1, 28), Decimal('41049'), 'car'),
#  (210, datetime.date(2022, 2, 15), Decimal('101467'), 'personal'),
#  (1, datetime.date(2022, 3, 24), Decimal('87435'), 'car'),
#  (282, datetime.date(2022, 3, 24), Decimal('121069'), 'mortgage'),
#  (280, datetime.date(2022, 3, 7), Decimal('68929'), 'personal'),
#  (271, datetime.date(2022, 3, 14), Decimal('86787'), 'mortgage'),
#  (227, datetime.date(2022, 1, 31), Decimal('165942'), 'mortgage'),
#  (286, datetime.date(2022, 4, 6), Decimal('16380'), 'car'),
#  (95, datetime.date(2022, 1, 31), Decimal('20160'), 'personal'),
#  (267, datetime.date(2022, 1, 12), Decimal('134996'), 'mortgage'),
#  (284, datetime.date(2022, 1, 16), Decimal('159759'), 'personal'),
#  (126, datetime.date(2022, 1, 17), Decimal('133626'), 'personal'),
#  (281, datetime.date(2022, 4, 3), Decimal('124385'), 'car'),
#  (50, datetime.date(2022, 2, 12), Decimal('168308'), 'personal'),
#  (123, datetime.date(2022, 1, 11), Decimal('76458'), 'mortgage'),
#  (151, datetime.date(2022, 3, 24), Decimal('57558'), 'mortgage'),
#  (136, datetime.date(2022, 3, 10), Decimal('108071'), 'personal'),
#  (147, datetime.date(2022, 3, 18), Decimal('103599'), 'personal'),
#  (181, datetime.date(2022, 1, 3), Decimal('33656'), 'personal'),
#  (136, datetime.date(2022, 2, 11), Decimal('22017'), 'car'),
#  (300, datetime.date(2022, 2, 14), Decimal('130415'), 'personal'),
#  (154, datetime.date(2022, 1, 3), Decimal('99160'), 'mortgage'),
#  (128, datetime.date(2022, 2, 16), Decimal('95172'), 'mortgage'),
#  (44, datetime.date(2022, 4, 3), Decimal('37105'), 'car'),
#  (225, datetime.date(2022, 1, 3), Decimal('78484'), 'mortgage'),
#  (86, datetime.date(2022, 1, 26), Decimal('189413'), 'mortgage'),
#  (147, datetime.date(2022, 1, 28), Decimal('188427'), 'car'),
#  (242, datetime.date(2022, 1, 27), Decimal('73543'), 'personal'),
#  (8, datetime.date(2022, 4, 6), Decimal('145411'), 'mortgage'),
#  (89, datetime.date(2022, 1, 11), Decimal('155954'), 'car'),
#  (123, datetime.date(2022, 1, 21), Decimal('63570'), 'personal'),
#  (135, datetime.date(2022, 2, 13), Decimal('188202'), 'personal'),
#  (234, datetime.date(2022, 1, 8), Decimal('187802'), 'personal'),
#  (8, datetime.date(2022, 1, 13), Decimal('148282'), 'personal'),
#  (232, datetime.date(2022, 2, 8), Decimal('78386'), 'personal'),
#  (95, datetime.date(2022, 3, 20), Decimal('39098'), 'personal'),
#  (123, datetime.date(2022, 3, 6), Decimal('48213'), 'car'),
#  (211, datetime.date(2022, 2, 23), Decimal('147004'), 'mortgage')]

# %% [markdown]
# ## Task 4
# <p>The business strategy team is considering offering a more competitive rate to the US market. </p>
# <p>The analytic team want to compare the average interest rates offered by the company for the same loan type in different countries to determine if there are significant differences.</p>
# <p><img src="https://assets.datacamp.com/production/project_1748/img/lending_schema.png" alt="database schema"></p>
# <p>Write a query that returns the data for the analytics team. Your output should include <code>loan_type</code>, <code>country</code> and <code>avg_rate</code> columns.</p>

# %%
# %%sql
# postgresql:///lending
#
# -- Keep the two lines above
# -- Start your answers here..
#
# SELECT
#     l.loan_type,
#     c.country,
#     AVG(l.interest_rate) AS avg_rate
# FROM
#     loan AS l
# JOIN
#     client AS c ON l.client_id = c.client_id
# GROUP BY
#     l.loan_type, c.country
# ORDER BY
#     l.loan_type, country;
# Out:
# 9 rows affected.
# [('car', 'CA', Decimal('0.11203883495145631068')),
#  ('car', 'UK', Decimal('0.12261261261261261261')),
#  ('car', 'USA', Decimal('0.10363636363636363636')),
#  ('mortgage', 'CA', Decimal('0.04406779661016949153')),
#  ('mortgage', 'UK', Decimal('0.04228070175438596491')),
#  ('mortgage', 'USA', Decimal('0.04385964912280701754')),
#  ('personal', 'CA', Decimal('0.21725274725274725275')),
#  ('personal', 'UK', Decimal('0.19873786407766990291')),
#  ('personal', 'USA', Decimal('0.20272058823529411765'))]
